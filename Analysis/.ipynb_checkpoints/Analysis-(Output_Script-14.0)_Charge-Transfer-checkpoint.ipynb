# %%
import os
import sys
import fnmatch
import pandas as pd
from os.path import isfile, join
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
#import seaborn as sns
#import magcolloids as mgc
from matplotlib.patches import Rectangle

#sys.path.insert(0, '../icenumerics')

#import icenumerics as ice

sys.path.insert(0, '../Scripts')
from importlib import reload  
import From_Cairo_to_Shakti as lattices
reload(lattices)

mpl.rc('text', usetex=False)
mpl.rcParams['figure.dpi'] = 75

mpl.rcParams['font.family'] = 'Arial'

mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["blue", "green", "purple", 
                                                    "orange", "royalblue", "limegreen", 
                                                    "blueviolet","darkorange", "tomato",
                                                    "red","black"])

# %% [markdown]
# # Vertex Count (theta)
#
# In this script, I will generate the vertex count plot for each theta value. Then I will save the last frame information, to build the transfer of charge picture.

# %%
data_directory = "/home/carolina/CairoLattice_ACI_PROJECT/Scripts/Output_Script-14.0"

# %%
#def count_vertices(vrt, exp = 'Exp', column = "type", column1 = "coordination", time = "frame"):
#    vrt_count = vrt.groupby([exp,time,column,column1]).count().iloc[:,0].to_frame("number")
#
#    vrt_count = vrt_count.reindex(pd.MultiIndex.from_product(
#        [vrt_count.index.get_level_values(exp).unique(),
#        vrt_count.index.get_level_values(time).unique(),
#        vrt_count.index.get_level_values(column).unique(),
#        vrt_count.index.get_level_values(column1).unique()]), fill_value = 0)

#    total_vrt = vrt_count.groupby([exp,time,column1]).sum()
#    array_coord = total_vrt.loc[vrt_count.index.get_level_values('frame')].number.values
#    array_coordT = np.tile(array_coord,int(len(vrt_count)/len(array_coord)))# 9 times of charges and 10 experiments 
#    vrt_count["fraction"] = vrt_count.number / array_coordT
        
#    return vrt_count

# %%
def count_vertices(vrt, exp = 'Exp', column = "type", column1 = "coordination", time = "frame"):
    vrt_count = vrt.groupby([exp,time,column,column1]).count().iloc[:,0].to_frame("number")

    vrt_count = vrt_count.reindex(pd.MultiIndex.from_product(
        [vrt_count.index.get_level_values(exp).unique(),
        vrt_count.index.get_level_values(time).unique(),
        vrt_count.index.get_level_values(column).unique(),
        vrt_count.index.get_level_values(column1).unique()]), fill_value = 0)

    total_vrt = vrt_count.groupby([exp,time,column1]).sum()
    array_coord = total_vrt.loc[vrt_count.index.get_level_values('frame')].number.values
    #array_coordT = np.tile(array_coord,9*10)# 9 times of charges and 10 experiments 
    print(len(vrt_count),len(array_coord))
    #array_coordT = np.tile(array_coord,round(int(len(vrt_count)/len(array_coord))))# 9 types of charges and 10 experiments 
    array_coordT = np.tile(array_coord[:2],int(len(vrt_count)/2))

    vrt_count["fraction"] = vrt_count.number / array_coordT
        
    return vrt_count

# %%
theta = np.linspace(np.pi/6, 5*np.pi/180, num= 15, endpoint=True, retstep=False, dtype=None, axis=0)
theta
# Out:
# array([0.52359878, 0.49243218, 0.46126559, 0.43009899, 0.3989324 ,
#        0.36776581, 0.33659921, 0.30543262, 0.27426603, 0.24309943,
#        0.21193284, 0.18076624, 0.14959965, 0.11843306, 0.08726646])

# %%
last_frame = []
for i in range(0,15):
    
    Lattices = []
    keys_Lattices = []
    for file in os.listdir(data_directory):
        if fnmatch.fnmatch(file, f"ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta{theta[i]}_exp*.dat"):
            print(file)
            Lattices.append(pd.read_csv(join(data_directory,file), sep = "\t", index_col = [0,1])) 
            keys_Lattices.append(theta[i])
    
    print(len(Lattices))
    #e = np.arange(0,10)
    e = np.arange(0,len(Lattices))
    Lattices_exp = pd.concat(Lattices, keys = e)
    print(len(Lattices_exp))

    Lattices_exp.index.names = ['Exp', 'frame', 'id']
    Lattices_exp

### Filter the vertices at the boundaries 

    First_frame = Lattices_exp.loc[0,0]

    d = 13 # Interparticle distance
    trap_sep_l = 10 # trap_sep parameter of the edge connecting 3 coordination and 4 coordination vertices
    s_l4 = d*np.sqrt(2)/2

    # <Generating lattice parameters depending on theta value>
    trap_sep_a, s_l3, a, l, plaquette_cte = lattices.lattice_parameters(theta[i], d, trap_sep_l, s_l4)

    x_min = plaquette_cte/2
    y_min = plaquette_cte

    width = plaquette_cte*16
    hight = plaquette_cte*16

    x_max = x_min+width
    y_max = y_min+hight

    #print(x_min,x_max,y_min,y_max)

    #fig =plt.figure(figsize = (15,15))
    #ax = fig.add_subplot(111)

    #plt.plot(First_frame.x, First_frame.y , 'o')
    #ax.add_patch(Rectangle((x_min, y_min),width, hight,fc ='none', ec ='g',lw = 5))

    Ca = Lattices_exp.loc[(Lattices_exp['x']<x_max) & (Lattices_exp['x']>x_min)]
    Lattices_exp = Ca.loc[(Ca['y']<y_max) & (Ca['y']>y_min)]

    ### Classify vertices

    Lattices_exp["type"] = np.NaN

    # 4-fold vertices classification

    Lattices_exp.loc[Lattices_exp.charge==-4, "type"] = "Q = -4"
    Lattices_exp.loc[Lattices_exp.charge==-2, "type"] = "Q = -2"
    Lattices_exp.loc[Lattices_exp.charge==+2, "type"] = "Q = +2"
    Lattices_exp.loc[Lattices_exp.charge==+4, "type"] = "Q = +4"

    zeroq = Lattices_exp.charge==0

    dipole_magnitude = np.sqrt(Lattices_exp[zeroq].dx**2+Lattices_exp[zeroq].dy**2)

    Lattices_exp.loc[zeroq & (dipole_magnitude<1), "type"] = "Q = 0"
    Lattices_exp.loc[zeroq & (dipole_magnitude>2) , "type"] = "Q = 0"

    # 3-fold vertices classification

    Lattices_exp.loc[Lattices_exp.charge==+1, "type"] = "Q = +1"
    Lattices_exp.loc[Lattices_exp.charge==-1, "type"] = "Q = -1"
    Lattices_exp.loc[Lattices_exp.charge==+3, "type"] = "Q = +3"
    Lattices_exp.loc[Lattices_exp.charge==-3, "type"] = "Q = -3"

    Lattices_exp =Lattices_exp.query('coordination == 4 or coordination == 3')

    count_m = count_vertices(Lattices_exp)

    v_counts_m = count_m.groupby(["frame","type","coordination"]).mean()
    v_counts_m["err"] = count_m['fraction'].groupby(["frame","type","coordination"]).std()/np.sqrt(count_m['fraction'].groupby(["frame","type","coordination"]).count().values)

    #v_counts_m = v_counts_m[(v_counts_m != 0).all(1)]
    v_counts_m = v_counts_m.query('number != 0')
    v_counts_m['time'] = v_counts_m.index.get_level_values('frame')
    
    last_frame.append(v_counts_m.loc[2500])
# Out:
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp29.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp24.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp41.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp15.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp9.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp37.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp42.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp30.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp43.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp16.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp2.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp27.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp11.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp7.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp1.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp6.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp23.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp28.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp31.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp26.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp5.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp12.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp25.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp8.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp38.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp19.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp21.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp34.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp22.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp0.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp14.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp20.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp33.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp13.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp18.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp17.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp10.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp35.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp4.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp32.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp3.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp36.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp40.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp39.0.dat
# 44
# 13252800
# /home/carolina/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/carolina/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# 198792 2510
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp10.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp11.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp37.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp7.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp2.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp6.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp39.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp12.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp5.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp25.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp22.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp24.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp29.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp0.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp18.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp31.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp28.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp9.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp17.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp36.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp13.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp8.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp41.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp16.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp32.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp43.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp19.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp20.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp3.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp27.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp23.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp34.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp38.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp14.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp1.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp40.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp4.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp21.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp35.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp26.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp42.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp30.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp33.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp15.0.dat
# 44
# 13252800
# 198792 2510
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp25.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp29.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp39.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp33.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp20.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp37.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp18.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp6.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp16.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp0.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp40.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp15.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp38.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp31.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp24.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp22.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp28.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp41.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp36.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp30.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp5.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp43.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp21.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp8.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp26.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp10.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp7.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp27.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp19.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp13.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp23.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp9.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp14.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp3.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp32.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp11.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp35.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp34.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp1.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp12.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp17.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp4.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp2.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp42.0.dat
# 44
# 13252800
# 198792 2510
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp30.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp27.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp43.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp38.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp10.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp35.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp12.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp31.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp28.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp37.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp19.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp42.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp34.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp1.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp8.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp9.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp0.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp41.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp23.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp26.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp40.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp20.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp33.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp4.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp2.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp21.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp24.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp39.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp3.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp36.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp17.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp13.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp14.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp25.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp15.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp32.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp7.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp29.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp5.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp18.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp22.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp16.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp11.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp6.0.dat
# 44
# 13252800
# 198792 2510
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp3.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp24.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp29.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp32.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp39.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp10.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp8.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp28.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp14.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp5.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp23.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp12.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp37.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp16.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp30.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp22.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp20.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp2.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp36.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp33.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp1.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp18.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp19.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp21.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp35.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp9.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp15.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp4.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp26.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp38.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp17.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp13.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp42.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp41.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp25.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp34.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp27.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp43.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp0.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp7.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp40.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp6.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp31.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp11.0.dat
# 44
# 13252800
# 198792 2510
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp10.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp34.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp4.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp27.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp38.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp28.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp9.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp13.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp25.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp37.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp26.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp19.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp40.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp23.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp17.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp36.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp35.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp16.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp22.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp1.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp12.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp20.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp39.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp8.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp6.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp5.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp21.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp11.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp14.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp3.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp29.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp41.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp0.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp31.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp33.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp2.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp24.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp18.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp15.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp30.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp7.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp32.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp42.0.dat
# 43
# 12951600
# 194274 2510
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp16.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp13.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp32.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp42.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp4.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp38.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp2.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp3.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp20.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp23.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp27.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp6.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp24.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp19.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp14.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp36.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp37.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp22.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp18.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp40.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp10.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp1.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp5.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp8.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp7.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp34.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp29.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp41.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp15.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp9.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp12.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp26.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp17.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp39.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp35.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp33.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp0.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp28.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp30.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp25.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp31.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp11.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp21.0.dat
# 43
# 12951600
# 194274 2510
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp40.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp36.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp9.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp25.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp4.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp13.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp37.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp6.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp5.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp19.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp42.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp10.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp24.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp1.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp16.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp31.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp34.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp38.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp32.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp12.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp41.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp22.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp18.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp7.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp14.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp28.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp11.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp26.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp39.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp3.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp21.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp29.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp27.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp0.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp30.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp8.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp20.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp17.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp15.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp23.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp2.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp33.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp35.0.dat
# 43
# 12951600
# 194274 2510
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp27.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp34.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp7.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp36.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp14.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp35.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp20.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp16.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp33.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp19.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp8.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp15.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp37.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp31.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp5.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp10.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp22.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp12.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp13.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp3.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp17.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp0.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp26.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp28.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp9.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp25.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp6.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp40.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp11.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp39.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp21.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp32.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp24.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp42.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp41.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp29.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp1.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp4.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp38.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp23.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp18.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp2.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp30.0.dat
# 43
# 12951600
# 194274 2510
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp19.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp21.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp40.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp4.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp35.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp10.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp28.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp37.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp27.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp7.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp16.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp6.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp3.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp24.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp34.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp0.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp2.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp14.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp29.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp12.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp17.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp36.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp23.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp25.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp31.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp33.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp5.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp11.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp1.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp20.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp30.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp9.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp8.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp32.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp38.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp26.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp41.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp18.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp39.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp13.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp22.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp42.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp15.0.dat
# 43
# 12951600
# 194274 2510
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp36.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp31.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp22.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp14.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp7.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp32.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp11.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp5.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp21.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp20.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp3.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp1.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp23.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp10.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp42.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp39.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp18.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp33.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp9.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp26.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp38.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp6.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp19.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp0.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp34.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp40.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp30.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp37.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp17.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp2.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp8.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp4.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp24.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp25.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp29.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp15.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp35.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp27.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp12.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp13.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp28.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp16.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp41.0.dat
# 43
# 12951600
# 194274 2510
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp35.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp27.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp2.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp9.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp26.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp18.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp6.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp24.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp14.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp3.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp36.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp40.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp13.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp28.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp25.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp16.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp32.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp15.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp5.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp42.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp21.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp11.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp41.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp8.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp1.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp19.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp10.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp33.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp39.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp22.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp12.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp7.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp31.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp20.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp30.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp29.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp23.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp4.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp17.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp38.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp37.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp34.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp0.0.dat
# 43
# 12951600
# 194274 2510
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp34.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp24.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp15.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp10.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp38.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp12.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp28.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp27.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp20.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp22.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp6.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp11.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp13.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp40.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp4.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp17.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp16.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp14.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp30.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp5.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp36.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp8.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp39.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp26.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp37.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp31.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp25.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp42.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp35.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp29.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp0.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp18.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp9.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp23.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp3.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp21.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp33.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp1.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp19.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp41.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp2.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp7.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp32.0.dat
# 43
# 12951600
# 194274 2510
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp41.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp17.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp19.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp6.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp35.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp36.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp9.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp26.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp11.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp33.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp25.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp24.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp21.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp42.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp0.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp13.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp5.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp31.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp18.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp39.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp32.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp2.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp38.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp22.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp29.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp15.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp10.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp30.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp34.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp14.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp12.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp3.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp28.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp16.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp27.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp23.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp37.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp1.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp4.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp8.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp7.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp20.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp40.0.dat
# 43
# 12951600
# 194274 2510
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp1.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp30.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp16.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp11.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp8.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp27.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp19.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp4.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp15.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp5.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp38.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp42.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp10.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp21.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp22.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp17.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp34.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp39.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp29.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp7.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp20.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp25.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp14.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp9.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp24.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp3.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp35.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp36.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp31.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp41.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp23.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp26.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp37.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp18.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp33.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp12.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp40.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp28.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp6.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp13.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp2.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp0.0.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp32.0.dat
# 43
# 12951600
# 194274 2510

# %%
last_frame
# Out:
# [                         number  fraction       err  time
#  type   coordination
#  Q = +1 3             216.727273  0.436950  0.002167  2500
#  Q = +2 4              25.363636  0.105682  0.002291  2500
#  Q = +3 3               2.886364  0.005819  0.000557  2500
#  Q = +4 4               1.454545  0.006061  0.000851  2500
#  Q = -1 3             276.227273  0.556910  0.001993  2500
#  Q = -2 4               6.204545  0.025852  0.001536  2500
#  Q = -3 3               0.159091  0.000321  0.000112  2500
#  Q = 0  4             206.977273  0.862405  0.002708  2500,
#                           number  fraction       err  time
#  type   coordination
#  Q = +1 3             238.522727  0.465865  0.002152  2500
#  Q = +2 4              16.113636  0.062944  0.002164  2500
#  Q = +3 3               3.431818  0.006703  0.000569  2500
#  Q = +4 4               0.659091  0.002575  0.000538  2500
#  Q = -1 3             269.977273  0.527299  0.001944  2500
#  Q = -2 4               9.636364  0.037642  0.001858  2500
#  Q = -3 3               0.068182  0.000133  0.000075  2500
#  Q = -4 4               0.045455  0.000178  0.000124  2500
#  Q = 0  4             229.545455  0.896662  0.002274  2500,
#                           number  fraction       err  time
#  type   coordination
#  Q = +1 3             248.318182  0.484996  0.002016  2500
#  Q = +2 4               6.613636  0.025835  0.001788  2500
#  Q = +3 3               5.886364  0.011497  0.000690  2500
#  Q = +4 4               0.022727  0.000089  0.000089  2500
#  Q = -1 3             257.795455  0.503507  0.001674  2500
#  Q = -2 4              14.159091  0.055309  0.001901  2500
#  Q = -4 4               0.022727  0.000089  0.000089  2500
#  Q = 0  4             235.181818  0.918679  0.002283  2500,
#                           number  fraction       err  time
#  type   coordination
#  Q = +1 3             248.000000  0.500000  0.002212  2500
#  Q = +2 4               2.113636  0.008807  0.000653  2500
#  Q = +3 3               8.272727  0.016679  0.000888  2500
#  Q = -1 3             239.727273  0.483321  0.001637  2500
#  Q = -2 4              19.477273  0.081155  0.002632  2500
#  Q = -4 4               0.113636  0.000473  0.000202  2500
#  Q = 0  4             218.295455  0.909564  0.002821  2500,
#                           number  fraction       err  time
#  type   coordination
#  Q = +1 3             260.477273  0.525156  0.002503  2500
#  Q = +2 4               0.818182  0.003409  0.000595  2500
#  Q = +3 3              12.636364  0.025477  0.001252  2500
#  Q = -1 3             222.772727  0.449139  0.001808  2500
#  Q = -2 4              39.340909  0.163920  0.003430  2500
#  Q = -3 3               0.113636  0.000229  0.000098  2500
#  Q = -4 4               0.181818  0.000758  0.000245  2500
#  Q = 0  4             199.659091  0.831913  0.003373  2500,
#                           number  fraction       err  time
#  type   coordination
#  Q = +1 3             300.348837  0.568842  0.002440  2500
#  Q = +2 4               0.581395  0.002271  0.000416  2500
#  Q = +3 3              20.348837  0.038539  0.001136  2500
#  Q = -1 3             207.209302  0.392442  0.001866  2500
#  Q = -2 4              77.023256  0.300872  0.003632  2500
#  Q = -3 3               0.093023  0.000176  0.000085  2500
#  Q = -4 4               0.441860  0.001726  0.000417  2500
#  Q = 0  4             177.953488  0.695131  0.003649  2500,
#                           number  fraction       err  time
#  type   coordination
#  Q = +1 3             306.465116  0.598565  0.002394  2500
#  Q = +2 4               0.232558  0.000969  0.000272  2500
#  Q = +3 3              28.697674  0.056050  0.001466  2500
#  Q = -1 3             176.790698  0.345294  0.001724  2500
#  Q = -2 4             101.813953  0.424225  0.004225  2500
#  Q = -3 3               0.046512  0.000091  0.000063  2500
#  Q = -4 4               0.837209  0.003488  0.000553  2500
#  Q = 0  4             137.116279  0.571318  0.004231  2500,
#                           number  fraction       err  time
#  type   coordination
#  Q = +1 3             308.627907  0.622234  0.002641  2500
#  Q = +2 4               0.069767  0.000273  0.000154  2500
#  Q = +3 3              39.441860  0.079520  0.001728  2500
#  Q = -1 3             147.906977  0.298200  0.001662  2500
#  Q = -2 4             146.813953  0.573492  0.003941  2500
#  Q = -3 3               0.023256  0.000047  0.000047  2500
#  Q = -4 4               1.488372  0.005814  0.000615  2500
#  Q = 0  4             107.627907  0.420422  0.003861  2500,
#                           number  fraction       err  time
#  type   coordination
#  Q = +1 3             313.651163  0.632361  0.003015  2500
#  Q = +2 4               0.023256  0.000097  0.000097  2500
#  Q = +3 3              51.674419  0.104182  0.001763  2500
#  Q = -1 3             130.604651  0.263316  0.001923  2500
#  Q = -2 4             161.581395  0.673256  0.003653  2500
#  Q = -3 3               0.069767  0.000141  0.000079  2500
#  Q = -4 4               2.581395  0.010756  0.000912  2500
#  Q = 0  4              75.813953  0.315891  0.003459  2500,
#                           number  fraction       err  time
#  type   coordination
#  Q = +1 3             323.372093  0.631586  0.003047  2500
#  Q = +2 4               0.023256  0.000091  0.000091  2500
#  Q = +3 3              67.046512  0.130950  0.001697  2500
#  Q = -1 3             121.534884  0.237373  0.002070  2500
#  Q = -2 4             196.651163  0.768169  0.003364  2500
#  Q = -3 3               0.046512  0.000091  0.000063  2500
#  Q = -4 4               4.953488  0.019350  0.001247  2500
#  Q = 0  4              54.372093  0.212391  0.003612  2500,
#                           number  fraction       err  time
#  type   coordination
#  Q = +1 3             323.325581  0.631495  0.003409  2500
#  Q = +2 4               0.023256  0.000097  0.000097  2500
#  Q = +3 3              77.465116  0.151299  0.001913  2500
#  Q = -1 3             111.116279  0.217024  0.001956  2500
#  Q = -2 4             197.441860  0.822674  0.003536  2500
#  Q = -3 3               0.093023  0.000182  0.000088  2500
#  Q = -4 4               7.697674  0.032074  0.001795  2500
#  Q = 0  4              34.837209  0.145155  0.003022  2500,
#                           number  fraction       err  time
#  type   coordination
#  Q = +1 3             332.767442  0.630241  0.003540  2500
#  Q = +3 3              90.116279  0.170675  0.001892  2500
#  Q = -1 3             105.046512  0.198952  0.002133  2500
#  Q = -2 4             217.069767  0.847929  0.004054  2500
#  Q = -3 3               0.069767  0.000132  0.000074  2500
#  Q = -4 4              14.604651  0.057049  0.002408  2500
#  Q = 0  4              24.325581  0.095022  0.002844  2500,
#                           number  fraction       err  time
#  type   coordination
#  Q = +1 3             318.604651  0.622275  0.003507  2500
#  Q = +2 4               0.023256  0.000097  0.000097  2500
#  Q = +3 3              97.046512  0.189544  0.002064  2500
#  Q = -1 3              96.232558  0.187954  0.001908  2500
#  Q = -2 4             206.209302  0.859205  0.002982  2500
#  Q = -3 3               0.116279  0.000227  0.000116  2500
#  Q = -4 4              19.162791  0.079845  0.001985  2500
#  Q = 0  4              14.604651  0.060853  0.002538  2500,
#                           number  fraction       err  time
#  type   coordination
#  Q = +1 3             303.139535  0.611168  0.003394  2500
#  Q = +3 3             104.744186  0.211178  0.001800  2500
#  Q = -1 3              88.069767  0.177560  0.002132  2500
#  Q = -2 4             216.302326  0.844931  0.003583  2500
#  Q = -3 3               0.046512  0.000094  0.000066  2500
#  Q = -4 4              29.953488  0.117006  0.003046  2500
#  Q = 0  4               9.744186  0.038063  0.001915  2500,
#                           number  fraction       err  time
#  type   coordination
#  Q = +1 3             298.813953  0.602447  0.003281  2500
#  Q = +3 3             114.441860  0.230730  0.002107  2500
#  Q = -1 3              82.465116  0.166260  0.001969  2500
#  Q = -2 4             196.511628  0.818798  0.004225  2500
#  Q = -3 3               0.279070  0.000563  0.000155  2500
#  Q = -4 4              38.139535  0.158915  0.003874  2500
#  Q = 0  4               5.348837  0.022287  0.001604  2500]

# %%
LFrame = pd.concat(last_frame, keys = theta)

# %%
LFrame.index.names = ['theta', 'type', 'coordination']
LFrame.head(19)
# Out:
#                                   number  fraction       err  time
# theta    type   coordination
# 0.523599 Q = +1 3             216.727273  0.436950  0.002167  2500
#          Q = +2 4              25.363636  0.105682  0.002291  2500
#          Q = +3 3               2.886364  0.005819  0.000557  2500
#          Q = +4 4               1.454545  0.006061  0.000851  2500
#          Q = -1 3             276.227273  0.556910  0.001993  2500
#          Q = -2 4               6.204545  0.025852  0.001536  2500
#          Q = -3 3               0.159091  0.000321  0.000112  2500
#          Q = 0  4             206.977273  0.862405  0.002708  2500
# 0.492432 Q = +1 3             238.522727  0.465865  0.002152  2500
#          Q = +2 4              16.113636  0.062944  0.002164  2500
#          Q = +3 3               3.431818  0.006703  0.000569  2500
#          Q = +4 4               0.659091  0.002575  0.000538  2500
#          Q = -1 3             269.977273  0.527299  0.001944  2500
#          Q = -2 4               9.636364  0.037642  0.001858  2500
#          Q = -3 3               0.068182  0.000133  0.000075  2500
#          Q = -4 4               0.045455  0.000178  0.000124  2500
#          Q = 0  4             229.545455  0.896662  0.002274  2500
# 0.461266 Q = +1 3             248.318182  0.484996  0.002016  2500
#          Q = +2 4               6.613636  0.025835  0.001788  2500

# %%
fig, ax1 = plt.subplots(figsize=(10,7))


for typ_m, mtype in LFrame.groupby('type'):
    
    ax1.errorbar(mtype.index.get_level_values('theta'), mtype["fraction"],yerr = mtype["err"], fmt ='-o', label = typ_m,markersize = 10)

    
ax1.tick_params(axis='y', labelsize=30)
ax1.tick_params(axis='x', labelsize=30)  

ax1.legend(fontsize = 25, bbox_to_anchor=(1, 1))
ax1.set_xlabel(r'$\theta$ (rad)', size = 40)
ax1.set_ylabel('Charge population', size = 40)
ax1.text(0.25, 0.85 ,'At 25 mT', size = 30)
# Out:
# Text(0.25, 0.85, 'At 25 mT')

# %%
LFrame3 = LFrame.query('coordination == 3')
LFrame4= LFrame.query('coordination == 4')

# %%
mpl.rc('text', usetex=False)
mpl.rcParams['figure.dpi'] = 75

mpl.rcParams['font.family'] = 'Arial'

mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["blue", "navy", "tomato", 
                                                    "red", "plum", "blue", 
                                                    "navy", "tomato",
                                                    "red"])

# %%
fig, ax = plt.subplots(1, 2,figsize=(10,5))

for typ_m, mtype in LFrame3.groupby('type'):
    print(typ_m)
    
    ax[0].errorbar(mtype.index.get_level_values('theta'), mtype["fraction"],yerr = mtype["err"],fmt = '-o', label = typ_m)

for typ_m, mtype in LFrame4.groupby('type'):
    print(typ_m)
    ax[1].errorbar(mtype.index.get_level_values('theta'), mtype["fraction"],yerr = mtype["err"], fmt ='-o',label = typ_m)

ax[0].tick_params(axis='y', labelsize=30)
ax[0].tick_params(axis='x', labelsize=30)  

ax[0].legend(fontsize = 12)
ax[0].set_xlabel(r'$\theta$ (º)', size = 40)
ax[0].set_ylabel('Charge population', size = 40)

ax[1].tick_params(axis='y', labelsize=30)
ax[1].tick_params(axis='x', labelsize=30)  

ax[1].legend(fontsize = 12)
ax[1].set_xlabel(r'$\theta$ (º)', size = 40)


plt.tight_layout()
# Out:
# Q = +1
# Q = +3
# Q = -1
# Q = -3
# Q = +2
# Q = +4
# Q = -2
# Q = -4
# Q = 0

# %%
LFrame['charge'] = LFrame.index.get_level_values('type')

# %%
def charge_value(row):
    
    value = int(row['charge'][-2:])
    return value

# %%
LFrame['charge'] = LFrame.apply (lambda row: charge_value(row) , axis=1)

# %%
LFrame
# Out:
#                                   number  fraction       err  time  charge
# theta    type   coordination
# 0.523599 Q = +1 3             216.727273  0.436950  0.002167  2500       1
#          Q = +2 4              25.363636  0.105682  0.002291  2500       2
#          Q = +3 3               2.886364  0.005819  0.000557  2500       3
#          Q = +4 4               1.454545  0.006061  0.000851  2500       4
#          Q = -1 3             276.227273  0.556910  0.001993  2500      -1
# ...                                  ...       ...       ...   ...     ...
# 0.087266 Q = -1 3              82.465116  0.166260  0.001969  2500      -1
#          Q = -2 4             196.511628  0.818798  0.004225  2500      -2
#          Q = -3 3               0.279070  0.000563  0.000155  2500      -3
#          Q = -4 4              38.139535  0.158915  0.003874  2500      -4
#          Q = 0  4               5.348837  0.022287  0.001604  2500       0
#
# [117 rows x 5 columns]

# %%
LFrame['fraction*charge'] = LFrame['fraction']*LFrame['charge']
LFrame
# Out:
#                                   number  fraction       err  time  charge  \
# theta    type   coordination
# 0.523599 Q = +1 3             216.727273  0.436950  0.002167  2500       1
#          Q = +2 4              25.363636  0.105682  0.002291  2500       2
#          Q = +3 3               2.886364  0.005819  0.000557  2500       3
#          Q = +4 4               1.454545  0.006061  0.000851  2500       4
#          Q = -1 3             276.227273  0.556910  0.001993  2500      -1
# ...                                  ...       ...       ...   ...     ...
# 0.087266 Q = -1 3              82.465116  0.166260  0.001969  2500      -1
#          Q = -2 4             196.511628  0.818798  0.004225  2500      -2
#          Q = -3 3               0.279070  0.000563  0.000155  2500      -3
#          Q = -4 4              38.139535  0.158915  0.003874  2500      -4
#          Q = 0  4               5.348837  0.022287  0.001604  2500       0
#
#                               fraction*charge
# theta    type   coordination
# 0.523599 Q = +1 3                    0.436950
#          Q = +2 4                    0.211364
#          Q = +3 3                    0.017458
#          Q = +4 4                    0.024242
#          Q = -1 3                   -0.556910
# ...                                       ...
# 0.087266 Q = -1 3                   -0.166260
#          Q = -2 4                   -1.637597
#          Q = -3 3                   -0.001688
#          Q = -4 4                   -0.635659
#          Q = 0  4                    0.000000
#
# [117 rows x 6 columns]

# %%
sum_df = LFrame.groupby(['theta','coordination']).sum()

# %%
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["blue","red"])

# %%
for typ_m, mtype in sum_df.groupby(['coordination']):
    
    plt.plot(mtype.index.get_level_values('theta'), mtype['fraction*charge'],':o', label = typ_m)

plt.yticks(fontsize=30, ticks=[-2,-1,0,1])
plt.tick_params(axis='x', labelsize=30)  
plt.legend(title = 'lattice coordination', fontsize = 25, bbox_to_anchor=(1, 1), title_fontsize = 20)
plt.axhline(y=0, color='black',alpha = 0.7, linestyle='-')
plt.xlabel(r'$\theta$ (rad)', size = 40)
plt.ylabel(r'$\sum_{q} n_{z=3,4}q$', size = 40)
# Out:
# Text(0, 0.5, '$\\sum_{q} n_{z=3,4}q$')
