# %%
import os
import fnmatch
import pandas as pd
from os.path import isfile, join
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# # Vertex Count
#
#     In this script I will analyze the vertex count in a Cairo Lattice if we increse linearly up from 0 mT to 50 mT with a rate of 0.0333 mT/s (1500 s). Then, we are analyzing the output data of Script-1.2.
#
#     In this scripts there are 2 independent branches, run until 2 or run until 1 and then from 2

# %%
data_directory = "/home/carolina/CairoLattice_ACI_PROJECT/Scripts/Output_Script-1.2"

# %%
slope = 50/1500
slope
# Out:
# 0.03333333333333333

# %%
Cairo = []
for file in os.listdir(data_directory):
    if fnmatch.fnmatch(file, 'ACI_CairoLattice_50mT-1500s_l10_exp*.dat'):
        print(file)
        Cairo.append(pd.read_csv(join(data_directory,file), sep = "\t", index_col = [0,1])) 
        
keys_Cairo = []
for i in range(len(Cairo)):
    keys_Cairo.append(i)
# Out:
# ACI_CairoLattice_50mT-1500s_l10_exp4.dat
# ACI_CairoLattice_50mT-1500s_l10_exp11.dat
# ACI_CairoLattice_50mT-1500s_l10_exp13.dat
# ACI_CairoLattice_50mT-1500s_l10_exp9.dat
# ACI_CairoLattice_50mT-1500s_l10_exp44.dat
# ACI_CairoLattice_50mT-1500s_l10_exp21.dat
# ACI_CairoLattice_50mT-1500s_l10_exp36.dat
# ACI_CairoLattice_50mT-1500s_l10_exp28.dat
# ACI_CairoLattice_50mT-1500s_l10_exp41.dat
# ACI_CairoLattice_50mT-1500s_l10_exp17.dat
# ACI_CairoLattice_50mT-1500s_l10_exp37.dat
# ACI_CairoLattice_50mT-1500s_l10_exp7.dat
# ACI_CairoLattice_50mT-1500s_l10_exp12.dat
# ACI_CairoLattice_50mT-1500s_l10_exp20.dat
# ACI_CairoLattice_50mT-1500s_l10_exp39.dat
# ACI_CairoLattice_50mT-1500s_l10_exp15.dat
# ACI_CairoLattice_50mT-1500s_l10_exp5.dat
# ACI_CairoLattice_50mT-1500s_l10_exp40.dat
# ACI_CairoLattice_50mT-1500s_l10_exp24.dat
# ACI_CairoLattice_50mT-1500s_l10_exp16.dat
# ACI_CairoLattice_50mT-1500s_l10_exp47.dat
# ACI_CairoLattice_50mT-1500s_l10_exp35.dat
# ACI_CairoLattice_50mT-1500s_l10_exp46.dat
# ACI_CairoLattice_50mT-1500s_l10_exp0.dat
# ACI_CairoLattice_50mT-1500s_l10_exp42.dat
# ACI_CairoLattice_50mT-1500s_l10_exp2.dat
# ACI_CairoLattice_50mT-1500s_l10_exp19.dat
# ACI_CairoLattice_50mT-1500s_l10_exp18.dat
# ACI_CairoLattice_50mT-1500s_l10_exp26.dat
# ACI_CairoLattice_50mT-1500s_l10_exp38.dat
# ACI_CairoLattice_50mT-1500s_l10_exp49.dat
# ACI_CairoLattice_50mT-1500s_l10_exp43.dat
# ACI_CairoLattice_50mT-1500s_l10_exp30.dat
# ACI_CairoLattice_50mT-1500s_l10_exp29.dat
# ACI_CairoLattice_50mT-1500s_l10_exp31.dat
# ACI_CairoLattice_50mT-1500s_l10_exp8.dat
# ACI_CairoLattice_50mT-1500s_l10_exp14.dat
# ACI_CairoLattice_50mT-1500s_l10_exp23.dat
# ACI_CairoLattice_50mT-1500s_l10_exp10.dat
# ACI_CairoLattice_50mT-1500s_l10_exp33.dat
# ACI_CairoLattice_50mT-1500s_l10_exp27.dat
# ACI_CairoLattice_50mT-1500s_l10_exp45.dat
# ACI_CairoLattice_50mT-1500s_l10_exp1.dat
# ACI_CairoLattice_50mT-1500s_l10_exp32.dat
# ACI_CairoLattice_50mT-1500s_l10_exp48.dat
# ACI_CairoLattice_50mT-1500s_l10_exp3.dat
# ACI_CairoLattice_50mT-1500s_l10_exp22.dat
# ACI_CairoLattice_50mT-1500s_l10_exp34.dat
# ACI_CairoLattice_50mT-1500s_l10_exp25.dat
# ACI_CairoLattice_50mT-1500s_l10_exp6.dat

# %%
Cairo_exp = pd.concat(Cairo, keys = keys_Cairo)

# %%
Cairo_exp.index.names = ['Exp', 'frame', 'id']

# %%
Cairo_exp["type"] = np.NaN

# 4-fold vertices classification

Cairo_exp.loc[Cairo_exp.charge==-4, "type"] = "Q = -4"
Cairo_exp.loc[Cairo_exp.charge==-2, "type"] = "Q = -2"
Cairo_exp.loc[Cairo_exp.charge==+2, "type"] = "Q = +2"
Cairo_exp.loc[Cairo_exp.charge==+4, "type"] = "Q = +4"
Cairo_exp.loc[Cairo_exp.charge== 0, "type"] = "Q = 0"

# 3-fold vertices classification

Cairo_exp.loc[Cairo_exp.charge==+1, "type"] = "Q = +1"
Cairo_exp.loc[Cairo_exp.charge==-1, "type"] = "Q = -1"
Cairo_exp.loc[Cairo_exp.charge==+3, "type"] = "Q = +3"
Cairo_exp.loc[Cairo_exp.charge==-3, "type"] = "Q = -3"

# %%
Cairo_exp['field'] = (Cairo_exp.index.get_level_values('frame'))/100*slope

# %%
def count_types(data):
    
    data["mean"] = 0
    cats = ["Q = -4", "Q = -2", "Q = 0", "Q = +2", "Q = +4","Q = +1","Q = -1","Q = +3","Q = -3" ]
    zeros = pd.DataFrame(np.zeros(len(cats)), columns=["mean"], index = cats)
    zeros.index.name="type"
    counts = zeros+data.groupby("type").count()
    counts[counts.isna()]=0
    return counts

Cairo_exp["mean"]= 0

# %% [markdown]
# ### Branch 1. Separatieng the vertex count by coordination

# %%
count_m = Cairo_exp.loc[:,["type","field","coordination"]].groupby(["Exp","field","coordination"]).apply(count_types)
increase = (count_m/Cairo_exp.groupby(["Exp","field","coordination"]).count()).filter(["mean"])

# %%
a = increase.query('mean != 0')

# %%
a = a.reset_index()
del a['coordination']
a = a.set_index(['Exp', 'field','type'])

# %%
def evenly_spaced(series,space):
    series_w_space = pd.concat([
        series.droplevel([0,2]),series.droplevel([0,2]).reindex(space)]
    ).groupby(series.droplevel([0,2]).index.name).first().sort_index()
    
    series_w_space = series_w_space.interpolate(method="index")
    return series_w_space.loc[space]

# %%
field = np.linspace(0,50,75)


vert_prop_evenspace_m = a.groupby(["Exp","type"]).apply(evenly_spaced,field)

# %%
v_counts_m = vert_prop_evenspace_m.groupby(["field","type"]).mean()
v_counts_m["err"] = vert_prop_evenspace_m.groupby(
    ["field","type"]).std()/np.sqrt(vert_prop_evenspace_m.groupby(["field","type"]).count().values)

# %%
mpl.rc('text', usetex=False)
mpl.rcParams['figure.dpi'] = 75

mpl.rcParams['font.family'] = 'Arial'

mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["blue", "green", "purple", 
                                                    "orange", "royalblue", "limegreen", 
                                                    "blueviolet","darkorange", "tomato",
                                                    "red"])

# %%
v_counts_m
# Out:
#                   mean       err
# field type
# 0.0   Q = +1  0.249201  0.002048
#       Q = +2  0.084201  0.001242
#       Q = +3  0.083728  0.001614
#       Q = +4  0.020237  0.000707
#       Q = -1  0.253373  0.001965
# ...                ...       ...
# 50.0  Q = -1  0.351243  0.002488
#       Q = -2  0.045592  0.001141
#       Q = -3  0.051834  0.001253
#       Q = -4  0.002544  0.000316
#       Q = 0   0.156302  0.001475
#
# [675 rows x 2 columns]

# %%
fig, ax1 = plt.subplots(figsize=(15,10))

for typ_m, mtype in v_counts_m .groupby('type'):
    
    plt.errorbar(mtype.index.get_level_values("field"), mtype["mean"],yerr = mtype["err"], fmt ='-o', label = typ_m)

ax1.tick_params(axis='y', labelsize=30)
ax1.tick_params(axis='x', labelsize=30)  

ax1.legend(fontsize = 30, bbox_to_anchor=(1, 1))
ax1.set_xlabel('B (mT)', size = 40)
ax1.set_ylabel('Charge population', size = 40)

plt.tight_layout()

# %% [markdown]
# ### Branch 2 . Do the same but without separating the vertices by coordination

# %%
count_m = Cairo_exp.loc[:,["type","field"]].groupby(["Exp","field"]).apply(count_types)
increase = (count_m/Cairo_exp.groupby(["Exp","field"]).count()).filter(["mean"])

# %%
def evenly_spaced(series,space):
    series_w_space = pd.concat([
        series.droplevel([0,2]),series.droplevel([0,2]).reindex(space)]
    ).groupby(series.droplevel([0,2]).index.name).first().sort_index()
    
    series_w_space = series_w_space.interpolate(method="index")
    return series_w_space.loc[space]

# %%
field = np.linspace(0,50,75)


vert_prop_evenspace_m = increase.groupby(["Exp","type"]).apply(evenly_spaced,field)

# %%
v_counts_m = vert_prop_evenspace_m.groupby(["field","type"]).mean()
v_counts_m["err"] = vert_prop_evenspace_m.groupby(
    ["field","type"]).std()/np.sqrt(vert_prop_evenspace_m.groupby(["field","type"]).count().values)

# %%
mpl.rc('text', usetex=False)
mpl.rcParams['figure.dpi'] = 75

mpl.rcParams['font.family'] = 'Arial'

mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["blue", "green", "purple", 
                                                    "orange", "royalblue", "limegreen", 
                                                    "blueviolet","darkorange", "tomato",
                                                    "red"])

# %%
fig, ax1 = plt.subplots(figsize=(15,10))

for typ_m, mtype in v_counts_m .groupby('type'):
    
    plt.errorbar(mtype.index.get_level_values("field"), mtype["mean"],yerr = mtype["err"], fmt ='-o', label = typ_m)

ax1.tick_params(axis='y', labelsize=30)
ax1.tick_params(axis='x', labelsize=30)  

ax1.legend(fontsize = 30, bbox_to_anchor=(1, 1))
ax1.set_xlabel('B (mT)', size = 40)
ax1.set_ylabel('Charge population', size = 40)

plt.tight_layout()
