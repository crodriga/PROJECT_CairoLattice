# %%
import os
import fnmatch
from os.path import isfile, join

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib as mpl

# %% [markdown]
# # Plot Chirality
#
#     In this script, I will draw the evolution of the chirality by increasing the magnetic field strenght

# %%
data_directory = "/home/carolina/CairoLattice_ACI_PROJECT/Scripts/Output_Script-8.1"

# %%
Chi= []
for file in os.listdir(data_directory):
    if fnmatch.fnmatch(file, "ACI_CairoLattice_25mT-2500s_PeriodicBound_chirality_l10_exp*.dat"):
        print(file)
        
        df = pd.read_csv(os.path.join(data_directory,file), sep = '\t',index_col = [0,1])
        
        Chi.append(df)
        
    
keys_Chi = []
for i in range(len(Chi)):
    keys_Chi.append(i)
    
Chi_exp = pd.concat(Chi, keys = keys_Chi)
Chi_exp.index.names = ['Exp', 'frame','pentagon']
# Out:
# ACI_CairoLattice_25mT-2500s_PeriodicBound_chirality_l10_exp8.dat
# ACI_CairoLattice_25mT-2500s_PeriodicBound_chirality_l10_exp1.dat
# ACI_CairoLattice_25mT-2500s_PeriodicBound_chirality_l10_exp6.dat
# ACI_CairoLattice_25mT-2500s_PeriodicBound_chirality_l10_exp5.dat
# ACI_CairoLattice_25mT-2500s_PeriodicBound_chirality_l10_exp2.dat
# ACI_CairoLattice_25mT-2500s_PeriodicBound_chirality_l10_exp9.dat
# ACI_CairoLattice_25mT-2500s_PeriodicBound_chirality_l10_exp0.dat
# ACI_CairoLattice_25mT-2500s_PeriodicBound_chirality_l10_exp4.dat
# ACI_CairoLattice_25mT-2500s_PeriodicBound_chirality_l10_exp3.dat
# ACI_CairoLattice_25mT-2500s_PeriodicBound_chirality_l10_exp7.dat

# %%
Chi_exp
# Out:
#                               x           y    z         x_c         y_c  z_c  \
# Exp frame  pentagon
# 0   0      0          30.305868   10.865525  0.0   18.289541    0.000000    1
#            0          30.305868  -10.865525  0.0   18.289541    0.000000    1
#            0          10.865525   16.046114  0.0   18.289541    0.000000    1
#            0          10.865525  -16.046114  0.0   18.289541    0.000000    1
#            0           0.000000    0.000000  0.0   18.289541    0.000000    1
# ...                         ...         ...  ...         ...         ...  ...
# 9   250000 799       818.289550 -891.553169  0.0  834.335663 -898.977185    1
#            799       850.381777 -891.553169  0.0  834.335663 -898.977185    1
#            799       834.335663 -880.687645  0.0  834.335663 -898.977185    1
#            799       850.381777 -869.822120  0.0  834.335663 -898.977185    1
#            799       818.289550 -869.822120  0.0  834.335663 -898.977185    1
#
#                           dx       dy   dz  Chi
# Exp frame  pentagon
# 0   0      0        -5.00000  8.66025  0.0 -0.6
#            0         5.00000  8.66025  0.0 -0.6
#            0        -8.66025 -5.00000 -0.0 -0.6
#            0         8.66025 -5.00000  0.0 -0.6
#            0         0.00000  4.52580  0.0 -0.6
# ...                      ...      ...  ...  ...
# 9   250000 799       5.00000  8.66025  0.0  1.0
#            799       5.00000 -8.66025 -0.0  1.0
#            799       4.52580  0.00000  0.0  1.0
#            799       5.00000  8.66025  0.0  1.0
#            799       5.00000 -8.66025 -0.0  1.0
#
# [2040000 rows x 10 columns]

# %%
Chi_exp['abs_C']= abs(Chi_exp.Chi)

# %% [markdown]
#     Removing "Pentagons" from the boundaries

# %%
x_min = Chi_exp.x_c.min()
x_max = Chi_exp.x_c.max()

y_min = Chi_exp.y_c.min()
y_max = Chi_exp.y_c.max()

Chi_exp = Chi_exp[Chi_exp.x_c != x_min]
Chi_exp = Chi_exp[Chi_exp.x_c != x_max]
Chi_exp = Chi_exp[Chi_exp.y_c != y_max]
Chi_exp = Chi_exp[Chi_exp.y_c != y_min]

# %%
c = Chi_exp.groupby(level= 1).mean().filter(items=['Chi','abs_C'])

# %%
a = Chi_exp.groupby(level= 1).mean().filter(items=['abs_C'])
a['err'] = Chi_exp.groupby(level= 1).std().filter(items=['abs_C'])/10
a
# Out:
#            abs_C       err
# frame
# 0       0.372000  0.024074
# 5000    0.372053  0.024092
# 10000   0.372263  0.024068
# 15000   0.372947  0.023927
# 20000   0.373947  0.024052
# 25000   0.376316  0.024277
# 30000   0.376737  0.024324
# 35000   0.376895  0.024334
# 40000   0.378211  0.024527
# 45000   0.381053  0.024696
# 50000   0.383947  0.024870
# 55000   0.389316  0.025209
# 60000   0.394947  0.025534
# 65000   0.399789  0.025883
# 70000   0.408737  0.026400
# 75000   0.419158  0.027000
# 80000   0.429632  0.027585
# 85000   0.444105  0.028283
# 90000   0.458053  0.028874
# 95000   0.474421  0.029626
# 100000  0.486263  0.030223
# 105000  0.501684  0.030858
# 110000  0.517316  0.031557
# 115000  0.531316  0.032089
# 120000  0.547895  0.032603
# 125000  0.564105  0.032796
# 130000  0.575105  0.032990
# 135000  0.589737  0.033505
# 140000  0.598947  0.033611
# 145000  0.608526  0.033831
# 150000  0.616105  0.033972
# 155000  0.625368  0.033890
# 160000  0.627842  0.034239
# 165000  0.630789  0.034256
# 170000  0.636579  0.034125
# 175000  0.640211  0.034352
# 180000  0.640895  0.034470
# 185000  0.641421  0.034322
# 190000  0.641895  0.034369
# 195000  0.642421  0.034190
# 200000  0.647632  0.034242
# 205000  0.648474  0.034131
# 210000  0.646684  0.034175
# 215000  0.647000  0.034146
# 220000  0.645053  0.034415
# 225000  0.649526  0.034061
# 230000  0.648684  0.034209
# 235000  0.649368  0.034078
# 240000  0.649789  0.033880
# 245000  0.648211  0.034188
# 250000  0.649171  0.034067

# %%
fig, ax1 = plt.subplots(figsize=(10,7))

ax2 = ax1.twinx()


ax1.errorbar(a.index.get_level_values('frame')/100, a.abs_C, yerr = a.err,fmt = 'o', color = 'red')
ax1.plot(a.index.get_level_values('frame')/100, a.abs_C, 'o', color = 'red')

ax1.tick_params(axis='y', labelsize=30)
ax1.tick_params(axis='x', labelsize=30) 
ax1.set_yticks([0.3,0.4,0.5,0.6,0.7])

ax1.legend(fontsize = 25, bbox_to_anchor=(1.5, 0.95))
ax1.set_xlabel('time (s)', size = 40)
ax1.set_ylabel('Total Chirality', size = 40)

ax2.plot([0,2000,2500],[0,25,25],':', color = 'black', alpha = 0.5, lw = 5)


ax2.set_ylabel('B (mT)', size = 40)
ax2.tick_params(axis='y', labelsize=30)



plt.savefig('Chirality.png',  bbox_inches='tight')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
Chi_exp
# Out:
#                               x           y    z         x_c         y_c  z_c  \
# Exp frame  pentagon
# 0   0      0          30.305868   10.865525  0.0   18.289541    0.000000    1
#            0          30.305868  -10.865525  0.0   18.289541    0.000000    1
#            0          10.865525   16.046114  0.0   18.289541    0.000000    1
#            0          10.865525  -16.046114  0.0   18.289541    0.000000    1
#            0           0.000000    0.000000  0.0   18.289541    0.000000    1
# ...                         ...         ...  ...         ...         ...  ...
# 9   250000 798       845.201188 -850.381777  0.0  834.335663 -862.398104    1
#            798       823.470139 -850.381777  0.0  834.335663 -862.398104    1
#            798       850.381777 -869.822120  0.0  834.335663 -862.398104    1
#            798       818.289550 -869.822120  0.0  834.335663 -862.398104    1
#            798       834.335663 -880.687645  0.0  834.335663 -862.398104    1
#
#                           dx       dy   dz  Chi  abs_C
# Exp frame  pentagon
# 0   0      0        -5.00000  8.66025  0.0 -0.6    0.6
#            0         5.00000  8.66025  0.0 -0.6    0.6
#            0        -8.66025 -5.00000 -0.0 -0.6    0.6
#            0         8.66025 -5.00000  0.0 -0.6    0.6
#            0         0.00000  4.52580  0.0 -0.6    0.6
# ...                      ...      ...  ...  ...    ...
# 9   250000 798      -8.66025  5.00000 -0.0 -1.0    1.0
#            798      -8.66025 -5.00000  0.0 -1.0    1.0
#            798       5.00000  8.66025  0.0 -1.0    1.0
#            798       5.00000 -8.66025 -0.0 -1.0    1.0
#            798       4.52580  0.00000  0.0 -1.0    1.0
#
# [1938000 rows x 11 columns]

# %%
Sep_Chi = Chi_exp.groupby(['Exp','frame','Chi']).count().filter('x').rename(columns = {'x':'count'})

# %%
Sep_Chi
# Out:
#                  count
# Exp frame  Chi
# 0   0      -1.0    115
#            -0.6    650
#            -0.2   1140
#             0.2   1160
#             0.6    595
# ...                ...
# 9   250000 -0.6    525
#            -0.2    620
#             0.2    465
#             0.6    585
#             1.0    765
#
# [3060 rows x 1 columns]

# %%
Sep_Chi_count = Sep_Chi.groupby(['frame','Chi']).mean()/3800
Sep_Chi_count
# Out:
#                 count
# frame  Chi
# 0      -1.0  0.031316
#        -0.6  0.153684
#        -0.2  0.314737
#         0.2  0.313816
#         0.6  0.159211
# ...               ...
# 250000 -0.6  0.130658
#        -0.2  0.158553
#         0.2  0.150132
#         0.6  0.128816
#         1.0  0.218421
#
# [306 rows x 1 columns]

# %%
Sep_Chi_std = Sep_Chi.groupby(['frame','Chi']).std()/(3800*np.sqrt(10))
Sep_Chi_std
# Out:
#                 count
# frame  Chi
# 0      -1.0  0.001639
#        -0.6  0.002630
#        -0.2  0.003818
#         0.2  0.003319
#         0.6  0.002210
# ...               ...
# 250000 -0.6  0.003675
#        -0.2  0.005157
#         0.2  0.004308
#         0.6  0.004186
#         1.0  0.002520
#
# [306 rows x 1 columns]

# %%
Sep_Chi_count['err'] = Sep_Chi_std['count']

# %%
Sep_Chi_count
# Out:
#                 count       err
# frame  Chi
# 0      -1.0  0.031316  0.001639
#        -0.6  0.153684  0.002630
#        -0.2  0.314737  0.003818
#         0.2  0.313816  0.003319
#         0.6  0.159211  0.002210
# ...               ...       ...
# 250000 -0.6  0.130658  0.003675
#        -0.2  0.158553  0.005157
#         0.2  0.150132  0.004308
#         0.6  0.128816  0.004186
#         1.0  0.218421  0.002520
#
# [306 rows x 2 columns]

# %%
#Sep_Chi['count'] = Sep_Chi['count']/3800

# %%
mpl.rcParams["font.family"] = "Arial"
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["blue", "green", "purple", 
                                                    "orange", "royalblue", "limegreen", 
                                                    "blueviolet","darkorange", "tomato",
                                                    "red"]) 

fig, ax1 = plt.subplots(figsize=(10,7))

cm = plt.cm.get_cmap('seismic')

C = ax1.scatter(Sep_Chi_count.index.get_level_values('frame')/100, Sep_Chi_count['count'], c = Sep_Chi_count.index.get_level_values('Chi'), cmap=cm, )
#plt.errorbar(Sep_Chi_count.index.get_level_values('frame')/100, Sep_Chi_count['count'], yerr = Sep_Chi_count['err'], fmt = '.', markersize = 0, capsize=3, color='gray')
#plt.plot(Sep_Chi.index.get_level_values('frame'), Sep_Chi['count'], 'o')
divider = make_axes_locatable(ax1)
cax = divider.append_axes("right", size="5%", pad=0.05)


cbar = plt.colorbar(C, cax =cax)
cbar.set_label( 'Chirality, $\chi$',rotation=270, size = 30, labelpad=40)
cbar.ax.tick_params(labelsize=20) 
ax1.set_xlabel('time (s)', size = 40)
ax1.set_ylabel('$N_{\chi}/N_{p}$', size = 40)
ax1.tick_params(axis='y', labelsize=30)
ax1.tick_params(axis='x', labelsize=30)

# %%
fig, ax = plt.subplots(2, 1, figsize=(5,10))




#ax1.errorbar(a.index.get_level_values('frame')/100, a.abs_C, yerr = a.err,fmt = 'o', color = 'red')
ax[0].plot(a.index.get_level_values('frame')/100, a.abs_C, 'o', color = 'red')

ax[0].tick_params(axis='y', labelsize=30)
ax[0].tick_params(axis='x', labelsize=30) 
ax[0].set_yticks([0.3,0.4,0.5,0.6,0.7])

ax[0].legend(fontsize = 25, bbox_to_anchor=(1.5, 0.95))
#ax[0].set_xlabel('time (s)', size = 40)
ax[0].set_ylabel('$\chi$', size = 40)
ax[0].tick_params(axis='y', labelsize=30)

cm = plt.cm.get_cmap('seismic')

C = ax[1].scatter(Sep_Chi_count.index.get_level_values('frame')/100, Sep_Chi_count['count'], c = Sep_Chi_count.index.get_level_values('Chi'), cmap=cm, )
#plt.errorbar(Sep_Chi_count.index.get_level_values('frame')/100, Sep_Chi_count['count'], yerr = Sep_Chi_count['err'], fmt = '.', markersize = 0, capsize=3, color='gray')
#plt.plot(Sep_Chi.index.get_level_values('frame'), Sep_Chi['count'], 'o')
divider = make_axes_locatable(ax[1])
cax = divider.append_axes("right", size="5%", pad=0.05)


cbar = plt.colorbar(C, cax =cax)
cbar.set_label( 'Chirality, $\chi_{p}$',rotation=270, size = 30, labelpad=40)
cbar.ax.tick_params(labelsize=20) 
ax[1].set_xlabel('time (s)', size = 40)
ax[1].set_ylabel('$N_{\chi_{p}}/N_{p}$', size = 40)
ax[1].tick_params(axis='y', labelsize=30)
ax[1].tick_params(axis='x', labelsize=30) 




plt.savefig('Chirality_2500.png',  bbox_inches='tight')
plt.show()
