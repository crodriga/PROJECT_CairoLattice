# %%
import os
import fnmatch
import pandas as pd
from os.path import isfile, join
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# %% [markdown]
# # Topological charge
#
#     In this script I will analyze the topological charge in a Cairo Lattice if we increse linearly up from 0 mT to 25 mT. Then we are Analyzing the output data of Script-12.0

# %%
data_directory = "/home/carolina/CairoLattice_ACI_PROJECT/Scripts/Output_Script-12.0"

# %%
Cairo = []
for file in os.listdir(data_directory):
    if fnmatch.fnmatch(file, 'ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp*.dat'):
        print(file)
        Cairo.append(pd.read_csv(join(data_directory,file), sep = "\t", index_col = [0,1])) 
        
print(len(Cairo))        
keys_Cairo = []
for i in range(len(Cairo)):
    keys_Cairo.append(i)
# Out:
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp27.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp5.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp20.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp14.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp45.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp11.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp26.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp32.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp47.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp44.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp36.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp39.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp49.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp16.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp0.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp33.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp48.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp23.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp18.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp29.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp30.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp34.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp31.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp25.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp22.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp9.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp10.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp40.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp37.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp43.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp38.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp19.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp46.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp21.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp4.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp35.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp3.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp6.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp28.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp1.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp13.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp41.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp42.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp2.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp12.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp17.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp7.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp15.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp24.dat
# ACI_ShaktiLattice_25mT-2500s_FreeBound_l10_exp8.dat
# 50

# %%
Cairo_exp = pd.concat(Cairo, keys = keys_Cairo)

# %%
Cairo_exp.index.names = ['Exp', 'frame', 'id']

# %%
Cairo_exp
# Out:
#                           x            y  coordination  charge   dx   dy
# Exp frame id
# 0   0     0      -28.384776   -56.769553             3       1  1.0  0.0
#           1     1107.006276  1021.851947             3       1 -1.0  0.0
#           2     1050.236724  1050.236724             2       0 -1.0  1.0
#           3      965.082395   709.619408             3      -1  0.0 -1.0
#           4      823.158513  1021.851947             3       1 -1.0  2.0
# ...                     ...          ...           ...     ...  ...  ...
# 49  2500  1232  1107.006276   709.619408             2       0 -1.0  1.0
#           1233   652.849855   -85.154329             2       0 -1.0 -1.0
#           1234   -28.384776   936.697618             2       0  1.0 -1.0
#           1235   -28.384776   823.158513             2       0  1.0 -1.0
#           1236   -28.384776   766.388960             2       0  1.0  1.0
#
# [30986850 rows x 6 columns]

# %%
Cairo_exp = Cairo_exp.query('coordination != 2')

# %%
Cairo_exp['time'] = (Cairo_exp.index.get_level_values('frame'))
# Out:
# /home/carolina/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
First_frame = Cairo_exp.loc[0,0]

plaquette_cte = 56.7696

x_min = 2*plaquette_cte
y_min = plaquette_cte

width = plaquette_cte*15
hight = plaquette_cte*15

x_max = x_min+width
y_max = y_min+hight

print(x_min,x_max,y_min,y_max)

fig =plt.figure(figsize = (15,15))
ax = fig.add_subplot(111)

plt.plot(First_frame.x, First_frame.y , 'o')
ax.add_patch(Rectangle((x_min, y_min),width, hight,fc ='none', ec ='g',lw = 5))
# Out:
# 113.5392 965.0832 56.7696 908.3136

# %%
Ca = Cairo_exp.loc[(Cairo_exp['x']<x_max) & (Cairo_exp['x']>x_min)]
Cairo_exp = Ca.loc[(Ca['y']<y_max) & (Ca['y']>y_min)]

# %% [markdown]
# ## 1. Total topological charge

# %%
Topo_q = Cairo_exp.groupby('time').sum()/Cairo_exp.groupby('time').count()

# %%
Topo_q
# Out:
#                x           y  coordination    charge        dx        dy
# time
# 0     548.772342  492.002789      3.333333  0.001067  0.009778  0.000652
# 5     548.772342  492.002789      3.333333  0.001067  0.009778  0.000652
# 10    548.772342  492.002789      3.333333  0.001007  0.009778  0.000711
# 15    548.772342  492.002789      3.333333  0.001007  0.009422  0.001067
# 20    548.772342  492.002789      3.333333  0.001007  0.009185  0.000948
# ...          ...         ...           ...       ...       ...       ...
# 2480  548.772342  492.002789      3.333333 -0.002904  0.013630  0.018430
# 2485  548.772342  492.002789      3.333333 -0.003852  0.015704  0.015763
# 2490  548.772342  492.002789      3.333333 -0.004504  0.011437  0.015941
# 2495  548.772342  492.002789      3.333333 -0.004741  0.011852  0.014933
# 2500  548.772342  492.002789      3.333333 -0.004859  0.013511  0.013037
#
# [501 rows x 6 columns]

# %%
fig, ax1 = plt.subplots(figsize=(7,7))

plt.plot(Topo_q.index.get_level_values('time'), Topo_q.charge, 'o')

ax1.tick_params(axis='y', labelsize=35)
ax1.tick_params(axis='x', labelsize=35)  

ax1.set_xlabel('B (mT)', size = 40)
ax1.set_ylabel('$\sum$(Q) / N', size = 40)
ax1.set_ylim(-0.2,0.2)

plt.tight_layout()

# %% [markdown]
# ### 2. Total topological charge of each sublattice

# %%
Cairo_exp.groupby(['time','coordination']).sum()
# Out:
#                               x             y  charge     dx     dy
# time coordination
# 0    3             1.245382e+07  1.117651e+07     -40  196.0   80.0
#      4             6.067246e+06  5.428588e+06      76  134.0  -58.0
# 5    3             1.245382e+07  1.117651e+07     -40  196.0   80.0
#      4             6.067246e+06  5.428588e+06      76  134.0  -58.0
# 10   3             1.245382e+07  1.117651e+07     -42  196.0   82.0
# ...                         ...           ...     ...    ...    ...
# 2490 4             6.067246e+06  5.428588e+06  -29218  124.0  130.0
# 2495 3             1.245382e+07  1.117651e+07   29068  284.0  400.0
#      4             6.067246e+06  5.428588e+06  -29228  116.0  104.0
# 2500 3             1.245382e+07  1.117651e+07   29102  352.0  350.0
#      4             6.067246e+06  5.428588e+06  -29266  104.0   90.0
#
# [1002 rows x 5 columns]

# %%
df1 = Cairo_exp.groupby(['time','coordination']).sum()/Cairo_exp.groupby(['time','coordination']).count()

# %%
err = Cairo_exp.groupby(['time','coordination']).std()/np.sqrt(Cairo_exp.groupby(['time','coordination']).count())

# %%
df = df1['charge'].to_frame()
df['err'] = err['charge']

# %%
df
# Out:
#                      charge       err
# time coordination
# 0    3            -0.001778  0.011547
#      4             0.006756  0.018808
# 5    3            -0.001778  0.011547
#      4             0.006756  0.018808
# 10   3            -0.001867  0.011547
# ...                     ...       ...
# 2490 4            -2.597156  0.008999
# 2495 3             1.291911  0.008386
#      4            -2.598044  0.008992
# 2500 3             1.293422  0.008399
#      4            -2.601422  0.009005
#
# [1002 rows x 2 columns]

# %%
mpl.rc('text', usetex=False)
mpl.rcParams['figure.dpi'] = 75

mpl.rcParams['font.family'] = 'Arial'

mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["blue", "red", "purple", 
                                                    "orange", "royalblue", "limegreen", 
                                                    "blueviolet","darkorange", "tomato",
                                                    "red","black"])

# %%
fig, ax = plt.subplots(1, 1, figsize=(5,4))

for typ_m, mtype in df.groupby('coordination'):
    
    plt.errorbar(mtype.index.get_level_values("time"), mtype["charge"],yerr = mtype['err'],fmt ='o', label = typ_m)
    #plt.plot(mtype.index.get_level_values("time"), mtype["charge"],'-', label = typ_m)

    
ax.tick_params(axis='y', labelsize=35)
ax.tick_params(axis='x', labelsize=35) 
#ax.legend(fontsize = 12, title= 'Lattice coordination', title_fontsize = 12, ncol = 1)


ax.set_xlabel('time (s)', size = 40)
ax.set_ylabel('$\sum$(Q) / N', size = 40)


plt.tight_layout()
plt.savefig('ChargeTransfer_shakti_N=10.png', bbox_inches='tight')

# %%
def to_field(row):
    if row['sec'] < 2000:
        value = row['sec']*25/2000
    else:
        value = 25
    return value

df['sec'] = df.index.get_level_values('time')
df['mT'] = df.apply (lambda row: to_field(row) , axis=1)

# %%
df.to_csv('ChargeTransfer_Shakti_N=50.dat', sep = '\t')
