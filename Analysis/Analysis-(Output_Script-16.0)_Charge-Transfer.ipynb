# %%
import os
import sys
import fnmatch
import pandas as pd
from os.path import isfile, join
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
#import seaborn as sns
#import magcolloids as mgc
from matplotlib.patches import Rectangle

#sys.path.insert(0, '../icenumerics')

#import icenumerics as ice

sys.path.insert(0, '../Scripts')
from importlib import reload  
import From_Cairo_to_Shakti as lattices
reload(lattices)

mpl.rc('text', usetex=False)
mpl.rcParams['figure.dpi'] = 75

mpl.rcParams['font.family'] = 'Arial'

mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["blue", "green", "purple", 
                                                    "orange", "royalblue", "limegreen", 
                                                    "blueviolet","darkorange", "tomato",
                                                    "red","black"])

# %% [markdown]
# # Vertex Count (theta)
#
# In this script, I will generate the vertex count plot for each theta value. Then I will save the last frame information, to build the transfer of charge picture.

# %%
data_directory = "/home/carolina/CairoLattice_ACI_PROJECT/Scripts/Output_Script-16.0"

# %%
def count_vertices(vrt, exp = 'Exp', column = "type", column1 = "coordination", time = "frame"):
    vrt_count = vrt.groupby([exp,time,column,column1]).count().iloc[:,0].to_frame("number")

    vrt_count = vrt_count.reindex(pd.MultiIndex.from_product(
        [vrt_count.index.get_level_values(exp).unique(),
        vrt_count.index.get_level_values(time).unique(),
        vrt_count.index.get_level_values(column).unique(),
        vrt_count.index.get_level_values(column1).unique()]), fill_value = 0)

    total_vrt = vrt_count.groupby([exp,time,column1]).sum()
    array_coord = total_vrt.loc[vrt_count.index.get_level_values('frame')].number.values
    #array_coordT = np.tile(array_coord,9*10)# 9 times of charges and 10 experiments 
    print(len(vrt_count),len(array_coord))
    #array_coordT = np.tile(array_coord,round(int(len(vrt_count)/len(array_coord))))# 9 types of charges and 10 experiments 
    array_coordT = np.tile(array_coord[:2],int(len(vrt_count)/2))

    vrt_count["fraction"] = vrt_count.number / array_coordT
        
    return vrt_count

# %%
theta = np.linspace(np.pi/6, 5*np.pi/180, num= 15, endpoint=True, retstep=False, dtype=None, axis=0)
theta
# Out:
# array([0.52359878, 0.49243218, 0.46126559, 0.43009899, 0.3989324 ,
#        0.36776581, 0.33659921, 0.30543262, 0.27426603, 0.24309943,
#        0.21193284, 0.18076624, 0.14959965, 0.11843306, 0.08726646])

# %%
last_frame = []
for i in range(0,15):
    
    Lattices = []
    keys_Lattices = []
    for file in os.listdir(data_directory):
        if fnmatch.fnmatch(file, f"ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta{theta[i]}_exp*_keepingTLength.dat"):
            print(file)
            Lattices.append(pd.read_csv(join(data_directory,file), sep = "\t", index_col = [0,1])) 
            keys_Lattices.append(theta[i])
    
    print(len(Lattices))
    #e = np.arange(0,10)
    e = np.arange(0,len(Lattices))
    Lattices_exp = pd.concat(Lattices, keys = e)
    print(len(Lattices_exp))

    Lattices_exp.index.names = ['Exp', 'frame', 'id']
    Lattices_exp

### Filter the vertices at the boundaries 

    First_frame = Lattices_exp.loc[0,0]

    d = 13 # Interparticle distance
    trap_sep_l = 10 # trap_sep parameter of the edge connecting 3 coordination and 4 coordination vertices
    s_l4 = d*np.sqrt(2)/2

    # <Generating lattice parameters depending on theta value>
    trap_sep_a, s_l3, a, l, plaquette_cte = lattices.lattice_parameters(theta[i], d, trap_sep_l, s_l4)

    x_min = plaquette_cte/2
    y_min = plaquette_cte

    width = plaquette_cte*16
    hight = plaquette_cte*16

    x_max = x_min+width
    y_max = y_min+hight

    #print(x_min,x_max,y_min,y_max)

    #fig =plt.figure(figsize = (15,15))
    #ax = fig.add_subplot(111)

    #plt.plot(First_frame.x, First_frame.y , 'o')
    #ax.add_patch(Rectangle((x_min, y_min),width, hight,fc ='none', ec ='g',lw = 5))

    Ca = Lattices_exp.loc[(Lattices_exp['x']<x_max) & (Lattices_exp['x']>x_min)]
    Lattices_exp = Ca.loc[(Ca['y']<y_max) & (Ca['y']>y_min)]

    ### Classify vertices

    Lattices_exp["type"] = np.NaN

    # 4-fold vertices classification

    Lattices_exp.loc[Lattices_exp.charge==-4, "type"] = "Q = -4"
    Lattices_exp.loc[Lattices_exp.charge==-2, "type"] = "Q = -2"
    Lattices_exp.loc[Lattices_exp.charge==+2, "type"] = "Q = +2"
    Lattices_exp.loc[Lattices_exp.charge==+4, "type"] = "Q = +4"

    zeroq = Lattices_exp.charge==0

    dipole_magnitude = np.sqrt(Lattices_exp[zeroq].dx**2+Lattices_exp[zeroq].dy**2)

    Lattices_exp.loc[zeroq & (dipole_magnitude<1), "type"] = "Q = 0"
    Lattices_exp.loc[zeroq & (dipole_magnitude>2) , "type"] = "Q = 0"

    # 3-fold vertices classification

    Lattices_exp.loc[Lattices_exp.charge==+1, "type"] = "Q = +1"
    Lattices_exp.loc[Lattices_exp.charge==-1, "type"] = "Q = -1"
    Lattices_exp.loc[Lattices_exp.charge==+3, "type"] = "Q = +3"
    Lattices_exp.loc[Lattices_exp.charge==-3, "type"] = "Q = -3"

    Lattices_exp =Lattices_exp.query('coordination == 4 or coordination == 3')

    count_m = count_vertices(Lattices_exp)

    v_counts_m = count_m.groupby(["frame","type","coordination"]).mean()
    v_counts_m["err"] = count_m['fraction'].groupby(["frame","type","coordination"]).std()/np.sqrt(count_m['fraction'].groupby(["frame","type","coordination"]).count().values)

    #v_counts_m = v_counts_m[(v_counts_m != 0).all(1)]
    v_counts_m = v_counts_m.query('number != 0')
    v_counts_m['time'] = v_counts_m.index.get_level_values('frame')
    
    last_frame.append(v_counts_m.loc[2500])
# Out:
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp15.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp14.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp13.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp3.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp5.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp17.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp10.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp6.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp7.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp4.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp12.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp19.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp8.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp0.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp2.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp9.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp18.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp1.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp11.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.5235987755982988_exp16.0_keepingTLength.dat
# 20
# 6024000
# /home/carolina/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/carolina/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# 90360 1004
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp10.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp7.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp1.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp17.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp12.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp6.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp9.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp3.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp8.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp13.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp11.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp5.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp16.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp0.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp14.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp2.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp15.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp4.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp19.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4924321818126858_exp18.0_keepingTLength.dat
# 20
# 6024000
# 90360 1004
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp11.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp8.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp0.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp12.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp10.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp17.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp4.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp6.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp15.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp9.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp3.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp19.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp5.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp2.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp18.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp1.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp16.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp7.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp13.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.4612655880270728_exp14.0_keepingTLength.dat
# 20
# 6024000
# 90360 1004
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp6.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp4.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp16.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp8.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp15.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp2.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp14.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp11.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp12.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp17.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp1.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp10.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp9.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp5.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp19.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp13.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp18.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp0.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp7.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.43009899424145975_exp3.0_keepingTLength.dat
# 20
# 6024000
# 90360 1004
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp16.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp15.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp0.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp10.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp17.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp4.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp13.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp7.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp1.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp18.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp3.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp11.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp6.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp9.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp14.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp5.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp2.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp19.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp12.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3989324004558467_exp8.0_keepingTLength.dat
# 20
# 6024000
# 90360 1004
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp2.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp17.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp8.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp18.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp7.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp14.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp10.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp13.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp1.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp3.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp15.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp19.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp4.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp6.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp0.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp5.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp11.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp16.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp12.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.36776580667023373_exp9.0_keepingTLength.dat
# 20
# 6024000
# 90360 1004
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp6.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp12.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp2.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp14.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp16.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp5.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp19.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp10.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp9.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp4.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp1.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp13.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp17.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp3.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp7.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp11.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp18.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp0.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp15.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.3365992128846207_exp8.0_keepingTLength.dat
# 20
# 6024000
# 90360 1004
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp13.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp10.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp9.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp15.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp5.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp2.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp6.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp3.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp19.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp7.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp11.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp1.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp17.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp18.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp4.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp0.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp16.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp8.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp14.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.30543261909900765_exp12.0_keepingTLength.dat
# 20
# 6024000
# 90360 1004
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp0.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp15.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp12.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp11.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp17.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp9.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp7.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp10.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp14.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp8.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp6.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp1.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp4.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp3.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp16.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp2.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp13.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp19.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp18.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2742660253133946_exp5.0_keepingTLength.dat
# 20
# 6024000
# 90360 1004
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp16.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp19.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp6.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp15.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp8.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp1.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp2.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp17.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp0.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp13.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp5.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp18.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp12.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp3.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp4.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp9.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp7.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp14.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp10.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.24309943152778163_exp11.0_keepingTLength.dat
# 20
# 6024000
# 90360 1004
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp0.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp17.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp5.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp3.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp8.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp16.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp13.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp2.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp10.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp15.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp9.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp19.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp18.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp14.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp4.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp1.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp6.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp11.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp7.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.2119328377421686_exp12.0_keepingTLength.dat
# 20
# 6024000
# 90360 1004
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp8.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp19.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp5.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp11.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp10.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp6.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp4.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp18.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp12.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp16.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp7.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp0.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp13.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp14.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp1.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp17.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp9.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp3.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp15.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.18076624395655555_exp2.0_keepingTLength.dat
# 20
# 6024000
# 90360 1004
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp19.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp4.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp11.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp15.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp7.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp12.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp5.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp18.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp3.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp8.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp16.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp9.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp14.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp17.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp1.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp13.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp10.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp6.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp2.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.14959965017094257_exp0.0_keepingTLength.dat
# 20
# 6024000
# 90360 1004
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp15.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp8.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp12.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp14.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp13.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp1.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp3.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp0.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp11.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp4.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp16.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp2.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp5.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp9.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp19.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp10.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp18.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp7.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp17.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.11843305638532953_exp6.0_keepingTLength.dat
# 20
# 6024000
# 90360 1004
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp15.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp5.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp9.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp0.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp10.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp19.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp14.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp17.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp3.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp11.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp1.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp12.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp7.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp16.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp13.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp2.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp6.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp4.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp18.0_keepingTLength.dat
# ACI_from_Cairo_to_Shakti_Lattice_25mT-2500s_FreeBound_theta0.08726646259971647_exp8.0_keepingTLength.dat
# 20
# 6024000
# 90360 1004

# %%
last_frame
# Out:
# [                     number  fraction       err  time
#  type   coordination
#  Q = +1 3             215.70  0.434879  0.002944  2500
#  Q = +2 4              25.65  0.106875  0.004486  2500
#  Q = +3 3               2.75  0.005544  0.000684  2500
#  Q = +4 4               1.45  0.006042  0.001068  2500
#  Q = -1 3             277.50  0.559476  0.002731  2500
#  Q = -2 4               4.90  0.020417  0.001957  2500
#  Q = -3 3               0.05  0.000101  0.000101  2500
#  Q = 0  4             208.00  0.866667  0.004574  2500,
#                       number  fraction       err  time
#  type   coordination
#  Q = +1 3             251.35  0.490918  0.002228  2500
#  Q = +2 4               9.70  0.037891  0.002778  2500
#  Q = +3 3               3.35  0.006543  0.000767  2500
#  Q = +4 4               0.15  0.000586  0.000320  2500
#  Q = -1 3             257.25  0.502441  0.002043  2500
#  Q = -2 4              14.55  0.056836  0.003656  2500
#  Q = -3 3               0.05  0.000098  0.000098  2500
#  Q = -4 4               0.05  0.000195  0.000195  2500
#  Q = 0  4             231.55  0.904492  0.004591  2500,
#                       number  fraction       err  time
#  type   coordination
#  Q = +1 3             267.45  0.522363  0.002061  2500
#  Q = +2 4               2.85  0.011133  0.001730  2500
#  Q = +3 3               4.10  0.008008  0.000748  2500
#  Q = +4 4               0.05  0.000195  0.000195  2500
#  Q = -1 3             240.35  0.469434  0.002025  2500
#  Q = -2 4              27.25  0.106445  0.004115  2500
#  Q = -3 3               0.10  0.000195  0.000134  2500
#  Q = -4 4               0.10  0.000391  0.000269  2500
#  Q = 0  4             225.75  0.881836  0.004707  2500,
#                       number  fraction       err  time
#  type   coordination
#  Q = +1 3             279.40  0.563306  0.002897  2500
#  Q = +2 4               1.90  0.007917  0.001538  2500
#  Q = +3 3               4.95  0.009980  0.000821  2500
#  Q = -1 3             211.55  0.426512  0.002497  2500
#  Q = -2 4              44.00  0.183333  0.004524  2500
#  Q = -3 3               0.10  0.000202  0.000139  2500
#  Q = -4 4               0.15  0.000625  0.000341  2500
#  Q = 0  4             193.95  0.808125  0.005152  2500,
#                       number  fraction       err  time
#  type   coordination
#  Q = +1 3             303.10  0.611089  0.002078  2500
#  Q = +2 4               0.55  0.002292  0.000707  2500
#  Q = +3 3               9.50  0.019153  0.001579  2500
#  Q = -1 3             183.30  0.369556  0.002439  2500
#  Q = -2 4              72.90  0.303750  0.008054  2500
#  Q = -3 3               0.10  0.000202  0.000139  2500
#  Q = -4 4               0.25  0.001042  0.000513  2500
#  Q = 0  4             166.30  0.692917  0.007860  2500,
#                       number  fraction       err  time
#  type   coordination
#  Q = +1 3             338.85  0.641761  0.003058  2500
#  Q = +2 4               0.55  0.002148  0.000721  2500
#  Q = +3 3              13.00  0.024621  0.001421  2500
#  Q = -1 3             176.10  0.333523  0.002991  2500
#  Q = -2 4              99.55  0.388867  0.006886  2500
#  Q = -3 3               0.05  0.000095  0.000095  2500
#  Q = -4 4               0.60  0.002344  0.000594  2500
#  Q = 0  4             155.30  0.606641  0.006713  2500,
#                       number  fraction       err  time
#  type   coordination
#  Q = +1 3             333.10  0.650586  0.003231  2500
#  Q = +2 4               0.20  0.000833  0.000487  2500
#  Q = +3 3              22.40  0.043750  0.001908  2500
#  Q = -1 3             156.45  0.305566  0.002070  2500
#  Q = -2 4             115.80  0.482500  0.004303  2500
#  Q = -3 3               0.05  0.000098  0.000098  2500
#  Q = -4 4               0.70  0.002917  0.000683  2500
#  Q = 0  4             123.30  0.513750  0.004244  2500,
#                       number  fraction       err  time
#  type   coordination
#  Q = +1 3             326.95  0.659173  0.004298  2500
#  Q = +2 4               0.15  0.000586  0.000320  2500
#  Q = +3 3              32.75  0.066028  0.002499  2500
#  Q = -1 3             136.30  0.274798  0.003701  2500
#  Q = -2 4             150.40  0.587500  0.007815  2500
#  Q = -4 4               1.90  0.007422  0.001264  2500
#  Q = 0  4             103.55  0.404492  0.007810  2500,
#                       number  fraction       err  time
#  type   coordination
#  Q = +1 3             327.50  0.660282  0.003152  2500
#  Q = +3 3              44.75  0.090222  0.001779  2500
#  Q = -1 3             123.75  0.249496  0.002884  2500
#  Q = -2 4             161.80  0.674167  0.006192  2500
#  Q = -4 4               2.55  0.010625  0.001299  2500
#  Q = 0  4              75.65  0.315208  0.006520  2500,
#                       number  fraction       err  time
#  type   coordination
#  Q = +1 3             334.45  0.653223  0.005240  2500
#  Q = +3 3              61.65  0.120410  0.002723  2500
#  Q = -1 3             115.90  0.226367  0.003101  2500
#  Q = -2 4             196.00  0.765625  0.003673  2500
#  Q = -4 4               5.30  0.020703  0.002179  2500
#  Q = 0  4              54.70  0.213672  0.003619  2500,
#                       number  fraction       err  time
#  type   coordination
#  Q = +1 3             328.65  0.641895  0.003744  2500
#  Q = +3 3              74.60  0.145703  0.002108  2500
#  Q = -1 3             108.65  0.212207  0.002990  2500
#  Q = -2 4             194.65  0.811042  0.005141  2500
#  Q = -3 3               0.10  0.000195  0.000134  2500
#  Q = -4 4               8.25  0.034375  0.002685  2500
#  Q = 0  4              37.10  0.154583  0.004390  2500,
#                       number  fraction       err  time
#  type   coordination
#  Q = +1 3             328.55  0.622254  0.006336  2500
#  Q = +3 3              91.60  0.173485  0.003095  2500
#  Q = -1 3             107.80  0.204167  0.004012  2500
#  Q = -2 4             216.35  0.845117  0.003392  2500
#  Q = -3 3               0.05  0.000095  0.000095  2500
#  Q = -4 4              14.50  0.056641  0.003488  2500
#  Q = 0  4              25.15  0.098242  0.003451  2500,
#                       number  fraction       err  time
#  type   coordination
#  Q = +1 3             311.50  0.608398  0.003315  2500
#  Q = +3 3             101.75  0.198730  0.002396  2500
#  Q = -1 3              98.70  0.192773  0.002039  2500
#  Q = -2 4             207.70  0.865417  0.004382  2500
#  Q = -3 3               0.05  0.000098  0.000098  2500
#  Q = -4 4              19.30  0.080417  0.004068  2500
#  Q = 0  4              13.00  0.054167  0.003242  2500,
#                       number  fraction       err  time
#  type   coordination
#  Q = +1 3             295.00  0.594758  0.005843  2500
#  Q = +3 3             108.65  0.219052  0.002908  2500
#  Q = -1 3              92.35  0.186190  0.003431  2500
#  Q = -2 4             214.80  0.839063  0.004396  2500
#  Q = -4 4              30.60  0.119531  0.003992  2500
#  Q = 0  4              10.60  0.041406  0.002051  2500,
#                       number  fraction       err  time
#  type   coordination
#  Q = +1 3             288.50  0.581653  0.004399  2500
#  Q = +3 3             120.60  0.243145  0.002995  2500
#  Q = -1 3              86.90  0.175202  0.002824  2500
#  Q = -2 4             193.25  0.805208  0.006866  2500
#  Q = -4 4              40.60  0.169167  0.005461  2500
#  Q = 0  4               6.15  0.025625  0.002981  2500]

# %%
LFrame = pd.concat(last_frame, keys = theta)

# %%
LFrame.index.names = ['theta', 'type', 'coordination']
LFrame.head(19)
# Out:
#                               number  fraction       err  time
# theta    type   coordination
# 0.523599 Q = +1 3             215.70  0.434879  0.002944  2500
#          Q = +2 4              25.65  0.106875  0.004486  2500
#          Q = +3 3               2.75  0.005544  0.000684  2500
#          Q = +4 4               1.45  0.006042  0.001068  2500
#          Q = -1 3             277.50  0.559476  0.002731  2500
#          Q = -2 4               4.90  0.020417  0.001957  2500
#          Q = -3 3               0.05  0.000101  0.000101  2500
#          Q = 0  4             208.00  0.866667  0.004574  2500
# 0.492432 Q = +1 3             251.35  0.490918  0.002228  2500
#          Q = +2 4               9.70  0.037891  0.002778  2500
#          Q = +3 3               3.35  0.006543  0.000767  2500
#          Q = +4 4               0.15  0.000586  0.000320  2500
#          Q = -1 3             257.25  0.502441  0.002043  2500
#          Q = -2 4              14.55  0.056836  0.003656  2500
#          Q = -3 3               0.05  0.000098  0.000098  2500
#          Q = -4 4               0.05  0.000195  0.000195  2500
#          Q = 0  4             231.55  0.904492  0.004591  2500
# 0.461266 Q = +1 3             267.45  0.522363  0.002061  2500
#          Q = +2 4               2.85  0.011133  0.001730  2500

# %%
fig, ax1 = plt.subplots(figsize=(10,7))


for typ_m, mtype in LFrame.groupby('type'):
    
    ax1.errorbar(mtype.index.get_level_values('theta'), mtype["fraction"],yerr = mtype["err"], fmt ='-o', label = typ_m,markersize = 10)

    
ax1.tick_params(axis='y', labelsize=30)
ax1.tick_params(axis='x', labelsize=30)  

ax1.legend(fontsize = 25, bbox_to_anchor=(1, 1))
ax1.set_xlabel(r'$\theta$ (rad)', size = 40)
ax1.set_ylabel('Charge population', size = 40)
ax1.text(0.25, 0.85 ,'At 25 mT', size = 30)
# Out:
# Text(0.25, 0.85, 'At 25 mT')

# %%
LFrame3 = LFrame.query('coordination == 3')
LFrame4= LFrame.query('coordination == 4')

# %%
mpl.rc('text', usetex=False)
mpl.rcParams['figure.dpi'] = 75

mpl.rcParams['font.family'] = 'Arial'

mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["blue", "navy", "tomato", 
                                                    "red", "plum", "blue", 
                                                    "navy", "tomato",
                                                    "red"])

# %%
fig, ax = plt.subplots(1, 2,figsize=(10,5))

for typ_m, mtype in LFrame3.groupby('type'):
    print(typ_m)
    
    ax[0].errorbar(mtype.index.get_level_values('theta'), mtype["fraction"],yerr = mtype["err"],fmt = '-o', label = typ_m)

for typ_m, mtype in LFrame4.groupby('type'):
    print(typ_m)
    ax[1].errorbar(mtype.index.get_level_values('theta'), mtype["fraction"],yerr = mtype["err"], fmt ='-o',label = typ_m)

ax[0].tick_params(axis='y', labelsize=30)
ax[0].tick_params(axis='x', labelsize=30)  

ax[0].legend(fontsize = 12)
ax[0].set_xlabel(r'$\theta$ (º)', size = 40)
ax[0].set_ylabel('Charge population', size = 40)

ax[1].tick_params(axis='y', labelsize=30)
ax[1].tick_params(axis='x', labelsize=30)  

ax[1].legend(fontsize = 12)
ax[1].set_xlabel(r'$\theta$ (º)', size = 40)


plt.tight_layout()
# Out:
# Q = +1
# Q = +3
# Q = -1
# Q = -3
# Q = +2
# Q = +4
# Q = -2
# Q = -4
# Q = 0

# %%
LFrame['charge'] = LFrame.index.get_level_values('type')

# %%
def charge_value(row):
    
    value = int(row['charge'][-2:])
    return value

# %%
LFrame['charge'] = LFrame.apply (lambda row: charge_value(row) , axis=1)

# %%
LFrame
# Out:
#                               number  fraction       err  time  charge
# theta    type   coordination
# 0.523599 Q = +1 3             215.70  0.434879  0.002944  2500       1
#          Q = +2 4              25.65  0.106875  0.004486  2500       2
#          Q = +3 3               2.75  0.005544  0.000684  2500       3
#          Q = +4 4               1.45  0.006042  0.001068  2500       4
#          Q = -1 3             277.50  0.559476  0.002731  2500      -1
# ...                              ...       ...       ...   ...     ...
# 0.087266 Q = +3 3             120.60  0.243145  0.002995  2500       3
#          Q = -1 3              86.90  0.175202  0.002824  2500      -1
#          Q = -2 4             193.25  0.805208  0.006866  2500      -2
#          Q = -4 4              40.60  0.169167  0.005461  2500      -4
#          Q = 0  4               6.15  0.025625  0.002981  2500       0
#
# [110 rows x 5 columns]

# %%
LFrame['fraction*charge'] = LFrame['fraction']*LFrame['charge']
LFrame
# Out:
#                               number  fraction       err  time  charge  \
# theta    type   coordination
# 0.523599 Q = +1 3             215.70  0.434879  0.002944  2500       1
#          Q = +2 4              25.65  0.106875  0.004486  2500       2
#          Q = +3 3               2.75  0.005544  0.000684  2500       3
#          Q = +4 4               1.45  0.006042  0.001068  2500       4
#          Q = -1 3             277.50  0.559476  0.002731  2500      -1
# ...                              ...       ...       ...   ...     ...
# 0.087266 Q = +3 3             120.60  0.243145  0.002995  2500       3
#          Q = -1 3              86.90  0.175202  0.002824  2500      -1
#          Q = -2 4             193.25  0.805208  0.006866  2500      -2
#          Q = -4 4              40.60  0.169167  0.005461  2500      -4
#          Q = 0  4               6.15  0.025625  0.002981  2500       0
#
#                               fraction*charge
# theta    type   coordination
# 0.523599 Q = +1 3                    0.434879
#          Q = +2 4                    0.213750
#          Q = +3 3                    0.016633
#          Q = +4 4                    0.024167
#          Q = -1 3                   -0.559476
# ...                                       ...
# 0.087266 Q = +3 3                    0.729435
#          Q = -1 3                   -0.175202
#          Q = -2 4                   -1.610417
#          Q = -4 4                   -0.676667
#          Q = 0  4                    0.000000
#
# [110 rows x 6 columns]

# %%
sum_df = LFrame.groupby(['theta','coordination']).sum()

# %%
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["blue","red"])

# %%
for typ_m, mtype in sum_df.groupby(['coordination']):
    
    plt.plot(mtype.index.get_level_values('theta'), mtype['fraction*charge'],':o', label = typ_m)

plt.yticks(fontsize=30, ticks=[-2,-1,0,1])
plt.tick_params(axis='x', labelsize=30)  
plt.legend(title = 'lattice coordination', fontsize = 25, bbox_to_anchor=(1, 1), title_fontsize = 20)
plt.axhline(y=0, color='black',alpha = 0.7, linestyle='-')
plt.xlabel(r'$\theta$ (rad)', size = 40)
plt.ylabel(r'$\sum_{q} n_{z=3,4}q$', size = 40)
# Out:
# Text(0, 0.5, '$\\sum_{q} n_{z=3,4}q$')
