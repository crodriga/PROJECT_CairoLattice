# %% [markdown]
# # From Lammpstrj to Vertex Dataframe
#
# In this script, I will convert the lammpstrj data to a vertex dataframe. This script will be usefull for all the simulations that I will run in a future. Since is a way to preprocess the data.

# %% [markdown]
# ### 1. Reading data and convert to dataframe

# %%
import magcolloids as mgc
import os
import sys
import numpy as np
import pandas as pd
from multiprocessing import Pool
import tqdm.auto as tqdm

sys.path.insert(0, '../icenumerics')

import icenumerics as ice
import matplotlib.pyplot as plt

# %%
data_directory = "/home/carolina/CairoLattice_ACI_PROJECT/Scripts/Output_Script-4.0"

# %%
def do_everything(exp_entry):
    
    e = exp_entry[1].e 
    l = exp_entry[1].l
    
    load_obj = mgc.trj_lazyread(os.path.join(data_directory,
                                             "ACI_CairoLattice_50mT-1200s_l%u_exp%u.lammpstrj"%(l,e)),
                                                output = ["x","y","z","mux","muy","muz"])    
    bnd = load_obj.get_bounds()
    trj = load_obj.read_trj()
    col_trj = ice.get_ice_trj(trj,bnd, atom_types = 1, trap_types = [2,3])
    
    # Infer Vertices
    frames = col_trj.index.get_level_values("frame").unique()

    v = ice.vertices()
    v.trj_to_vertices(col_trj.loc[frames[::10]])
    
    # Remove the vertices near the boundaries
    
    x_min = 95
    y_min = -75

    width = 700
    hight = -700

    x_max = x_min+width
    y_max = y_min+hight
    
    Ca = v.vertices.loc[(v.vertices['x']<x_max) & (v.vertices['x']>x_min)]
    Cairo = Ca.loc[(Ca['y']>y_max) & (Ca['y']<y_min)]
    
    #plt.plot(Cairo.loc[0].x,Cairo.loc[0].y, 'o')
    
    Cairo.index.names = ['frame', 'id']
    
    Cairo.to_csv(os.path.join(data_directory, "ACI_CairoLattice_50mT-1200s_l%u_exp%u.dat"%(l,e)), sep="\t")

# %%
e =  np.arange(21,50)
l =  [10]
L, E = np.meshgrid(l,e)
experiments = pd.DataFrame({"e":E.flatten(),"l":L.flatten()})
experiments
# Out:
#      e   l
# 0   21  10
# 1   22  10
# 2   23  10
# 3   24  10
# 4   25  10
# 5   26  10
# 6   27  10
# 7   28  10
# 8   29  10
# 9   30  10
# 10  31  10
# 11  32  10
# 12  33  10
# 13  34  10
# 14  35  10
# 15  36  10
# 16  37  10
# 17  38  10
# 18  39  10
# 19  40  10
# 20  41  10
# 21  42  10
# 22  43  10
# 23  44  10
# 24  45  10
# 25  46  10
# 26  47  10
# 27  48  10
# 28  49  10

# %%
if __name__ ==  '__main__': 
    num_processors = 5
    p=Pool(processes = num_processors)
        
    list(tqdm.tqdm(p.imap(do_everything, experiments.iterrows()), total=len(experiments)));
# Out:
# HBox(children=(FloatProgress(value=0.0, max=29.0), HTML(value='')))
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/carolina/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-3-dbde90630a86>", line 8, in do_everything
#     output = ["x","y","z","mux","muy","muz"])
#   File "/home/carolina/anaconda3/lib/python3.7/site-packages/magcolloids-0.3.10-py3.7.egg/magcolloids/simulation.py", line 299, in __init__
#     with open(Filename) as d:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/carolina/CairoLattice_ACI_PROJECT/Scripts/Output_Script-4.0/ACI_CairoLattice_50mT-1200s_l10_exp21.lammpstrj'
# """
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-3fe85b332bb4> in <module>
#       3     p=Pool(processes = num_processors)
#       4
# ----> 5     list(tqdm.tqdm(p.imap(do_everything, experiments.iterrows()), total=len(experiments)));
#
# ~/anaconda3/lib/python3.7/site-packages/tqdm/notebook.py in __iter__(self, *args, **kwargs)
#     215     def __iter__(self, *args, **kwargs):
#     216         try:
# --> 217             for obj in super(tqdm_notebook, self).__iter__(*args, **kwargs):
#     218                 # return super(tqdm...) will not catch exception
#     219                 yield obj
#
# ~/anaconda3/lib/python3.7/site-packages/tqdm/std.py in __iter__(self)
#    1105                 fp_write=getattr(self.fp, 'write', sys.stderr.write))
#    1106
# -> 1107         for obj in iterable:
#    1108             yield obj
#    1109             # Update and possibly print the progressbar.
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in next(self, timeout)
#     746         if success:
#     747             return value
# --> 748         raise value
#     749
#     750     __next__ = next                    # XXX
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/carolina/CairoLattice_ACI_PROJECT/Scripts/Output_Script-4.0/ACI_CairoLattice_50mT-1200s_l10_exp21.lammpstrj'
