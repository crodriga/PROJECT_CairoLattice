# %% [markdown]
# # Cairo, Reproducing experimental data
#
# In this script, I will build a 5x5 plaquette ice in order to have the same structure as in experimemtal realizations. I will leave the boundaries free to fully reproduce experimental conditions. The idea is to analyze the data with poor statistics and high statistics in order to observe if something changes. Also with this simulations we pretend to elucidate if radial polarization and charge accumulation at the boundaries is generating the end of the inverse charge transfer effect observed in bigger systems.

# %%
import os
import sys
import numpy as np
from importlib import reload  
import support as sup
reload(sup)
sys.path.insert(0, '../icenumerics')

import icenumerics as ice

from icenumerics.geometry import ordering 
import magcolloids as mgc

import matplotlib.pyplot as plt
ureg = ice.ureg
from string import Template

# %load_ext autoreload
# %autoreload 2

# %%
output = "/home/carolina/CairoLattice_ACI_PROJECT/Scripts/Output_Script-15.0"

# %%
centers, directions = sup.experimental_conf()

# %%
ureg = ice.ureg
sp = sup.spins()
sp = ice.spins(centers = centers, directions =directions, lattice_constant=19.5458*ureg.um )
sp.order_spins(ordering.random_ordering)


f, (ax1) = plt.subplots(1,1,figsize = (8,8))
sp.display(ax1)
plt.axis('square')
# Out:
# (15.64720689331488, 262.46468085920793, -216.11269956712079, 30.70477439877226)

# %%
particle = ice.particle(radius = 5*ureg.um,
             susceptibility = 0.005,
             diffusion = 0.125*ureg.um**2/ureg.s,
             temperature = 300*ureg.K,
             density = 1000*ureg.kg/ureg.m**3)

trap_long = ice.trap(trap_sep = 10*ureg.um,
               height = 30*ureg.pN*ureg.nm,
               stiffness = 0.1*ureg.fN/ureg.nm)

trap_short = ice.trap(trap_sep = 4.5258*ureg.um,
               height = 30*ureg.pN*ureg.nm,
               stiffness = 0.1*ureg.fN/ureg.nm)

traps = []

# %%
a = 19.5458*ureg.um 

for s in sp:
    
    if ( s.direction[0].magnitude == a.magnitude or s.direction[0].magnitude == -a.magnitude or 
        s.direction[1].magnitude == a.magnitude or s.direction[1].magnitude == -a.magnitude ):
        
        traps.append(trap_short)
        
    else:
        
        traps.append(trap_long)

# %%
col = ice.colloidal_ice(sp, particle, traps, height_spread = 0, susceptibility_spread = 0.1)

col.pad_region(7.1539*ureg.um) # Parameter obtained by geometric restrictions.

f, (ax1) = plt.subplots(1,1,figsize = (15,15))
col.display(ax1)
sp.display(ax1)

# %%
world = ice.world(
    field = 30*ureg.mT,
    temperature = 300*ureg.K,
    dipole_cutoff = 200*ureg.um)

total_time = 1000*ureg.s
col.simulate(world,
             name = 'test',
             #name = "MimicExperimentalData_CairoLattice_25mT-1000s_EXP30",
             include_timestamp = False,
             targetdir = output,
             framerate = 1*ureg.Hz,
             timestep = 10*ureg.ms,
             run_time = total_time,
             output = ["x","y","z","mux","muy","muz"])
# Out:
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10048328.0), HTML(value='')))

# %%
col.sim.field.fieldz = "v_Bmag*time/%f"%(total_time.to(ureg.us).magnitude)
col.run_simulation()

# %%
col.load_simulation(slice(0,None,1))
# Out:
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10159433.0), HTML(value='')))

# %%
f, (ax1) = plt.subplots(1,1,figsize = (15,15))
v = ice.vertices()
col.set_state_from_frame(-1)
v = v.colloids_to_vertices(col)

col.display(ax1)
v.display(ax1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=82.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=125.0), HTML(value='')))

# %%
v.vertices
# Out:
#              x           y  coordination  charge        dx        dy
# 0   254.928788 -115.906484             2       2  1.366025 -0.366025
# 1   241.532806  -92.703963             3       1  1.000000 -1.732051
# 2    36.579081    0.000000             3      -1 -2.000000  0.000000
# 3    23.183099  -23.202521             2       2 -1.366025 -0.366025
# 4   231.759906  -36.579081             3      -1  1.732051 -1.000000
# ..         ...         ...           ...     ...       ...       ...
# 77  139.055944 -148.828844             3       1 -1.732051 -1.000000
# 78  254.928788 -162.205404             2       0  0.366025 -1.366025
# 79   23.183099 -115.906484             2       2 -1.366025 -0.366025
# 80  162.205404 -208.576807             2       2 -0.366025 -1.366025
# 81  115.906484 -208.576807             2       2  0.366025 -1.366025
#
# [82 rows x 6 columns]

# %% [markdown]
# # Loop

# %%
for i in range(30,50):
    
    centers, directions = sup.experimental_conf()
    
    ureg = ice.ureg
    sp = sup.spins()
    sp = ice.spins(centers = centers, directions = directions, lattice_constant=19.5458*ureg.um )
    sp.order_spins(ordering.random_ordering)
    
    particle = ice.particle(radius = 5*ureg.um,
             susceptibility = 0.005,
             diffusion = 0.125*ureg.um**2/ureg.s,
             temperature = 300*ureg.K,
             density = 1000*ureg.kg/ureg.m**3)

    trap_long = ice.trap(trap_sep = 10*ureg.um,
                   height = 30*ureg.pN*ureg.nm,
                   stiffness = 0.1*ureg.fN/ureg.nm)

    trap_short = ice.trap(trap_sep = 4.5258*ureg.um,
                   height = 30*ureg.pN*ureg.nm,
                   stiffness = 0.1*ureg.fN/ureg.nm)

    traps = []
    
    a = 19.5458*ureg.um 

    for s in sp:

        if ( s.direction[0].magnitude == a.magnitude or s.direction[0].magnitude == -a.magnitude or 
            s.direction[1].magnitude == a.magnitude or s.direction[1].magnitude == -a.magnitude ):

            traps.append(trap_short)

        else:

            traps.append(trap_long)
            
    col = ice.colloidal_ice(sp, particle, traps, height_spread = 0, susceptibility_spread = 0.1)

    col.pad_region(7.1539*ureg.um) # Parameter obtained by geometric restrictions.
    
    world = ice.world(
    field = 25*ureg.mT,
    temperature = 300*ureg.K,
    dipole_cutoff = 200*ureg.um)

    total_time = 1000*ureg.s
    col.simulate(world,
                 name = "MimicExperimentalData_CairoLattice_25mT-1000s_EXP"+str(i),
                 include_timestamp = False,
                 targetdir = output,
                 framerate = 1*ureg.Hz,
                 timestep = 10*ureg.ms,
                 run_time = total_time,
                 output = ["x","y","z","mux","muy","muz"])
    
    col.sim.field.fieldz = "v_Bmag*time/%f"%(total_time.to(ureg.us).magnitude)
    col.run_simulation()
    col.load_simulation(slice(0,None,1))
# Out:
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10175317.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10162747.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10180733.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10165972.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10153677.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10140041.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10169602.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10157138.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10174572.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10160668.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10185985.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10171545.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10190424.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10176288.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10189507.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10174983.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10178096.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10164138.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10188726.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10175216.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10207746.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10193411.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10186298.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10172877.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10194115.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10179988.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10200573.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10186624.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10163531.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10149094.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10165313.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10151493.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10180815.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10166953.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10165779.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10151201.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10164671.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10151434.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10164097.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=10150327.0), HTML(value='')))
