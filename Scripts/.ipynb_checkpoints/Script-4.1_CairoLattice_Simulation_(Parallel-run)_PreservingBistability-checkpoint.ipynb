# %%
import os
import sys
import numpy as np
import pandas as pd
import csv as csv
import tqdm.auto as tqdm
from multiprocessing import Pool
from importlib import reload  
import support as sup
reload(sup)
sys.path.insert(0, '../icenumerics')

import icenumerics as ice
from icenumerics.geometry import ordering 
import magcolloids as mgc

import matplotlib.pyplot as plt
import time
ureg = ice.ureg

# %%
output = "/home/carolina/CairoLattice_ACI_PROJECT/Scripts/Output_Script-4.0"

# %%
1/1200
# Out:
# 0.0008333333333333334

# %% [markdown]
# # Cairo Lattice
#
#     In this script I will run the preliminarly simulations. I will run simulations in parallel and I will also extract the vertices pandas dataframes to analyze the vertex evolution in front of the interaction strenght.

# %%
def do_everything(exp_entry):
    
    e = exp_entry[1].e 
    l = exp_entry[1].l
    
    # <To change the seed of the thermal noise>
    
    np.random.seed()
    
    # <Introduce the parameters for the simulation>

    sp = sup.spins()
    ureg = ice.ureg
    sp.create_lattice(geometry = "cairo",size =[l,l],lattice_constant=19.5458*ureg.um, border="closed spin")
    sp.order_spins(ordering.random_ordering)

    particle = ice.particle(radius = 5*ureg.um,
                 susceptibility = 0.005,
                 diffusion = 0.125*ureg.um**2/ureg.s,
                 temperature = 300*ureg.K,
                 density = 1000*ureg.kg/ureg.m**3)

    trap_long = ice.trap(trap_sep = 10*ureg.um,
                   height = 6e-1*ureg.pN*ureg.nm,
                   stiffness = 6e-3*ureg.pN/ureg.nm)

    trap_short = ice.trap(trap_sep = 4.5258*ureg.um,
                   height = 6e-1*ureg.pN*ureg.nm,
                   stiffness = 6e-3*ureg.pN/ureg.nm)

    traps = []

    # <In this loop, I will define which traps have to be shortere>

    for s in sp:

        if ( s.direction[0].magnitude == 1.0 or s.direction[0].magnitude == -1.0 or 
            s.direction[1].magnitude == 1.0 or s.direction[1].magnitude == -1.0 ):

            traps.append(trap_short)

        else:

            traps.append(trap_long) 

    col = ice.colloidal_ice(sp, particle, traps, height_spread = 0, susceptibility_spread = 0.1)

    col.pad_region(30*ureg.um) # Why is this important?? Whitout this line the simulation do not run.  
    
    # <Introduce the simulation parameters>
    
    world = ice.world(
        field = 1*ureg.mT,
        temperature = 300*ureg.K,
        dipole_cutoff = 200*ureg.um)
    
    total_time = 1200*ureg.s
    col.simulate(world,
                 name = "ACI_CairoLattice_1mT-1200s_l%u_exp%u"%(l,e),
                 include_timestamp = False,
                 targetdir = output,
                 framerate = 1*ureg.Hz,
                 timestep = 10*ureg.ms,
                 run_time = total_time,
                 output = ["x","y","z","mux","muy","muz"])

    col.sim.field.fieldz = "v_Bmag*time/%f"%total_time.to(ureg.us).magnitude
    col.run_simulation()    
    
    # <Load simulation and compute vertices dataframes>
    
    col.load_simulation(slice(0,None,1))

    frames = col.trj.index.get_level_values("frame").unique()

    v_df = []

    for f in tqdm.tqdm(frames[::1]):
        col.set_state_from_frame(f)
        v = ice.vertices()
        v = v.colloids_to_vertices(col)

        v_df.append(v.vertices)

    v_df = pd.concat(v_df, keys=frames[::1], names = ["frame"])
    
    # <Save the dataframe and create index of the runned simulation>
    
    v_df.to_csv(os.path.join(output,"ACI_CairoLattice_1mT-1200s_l%u_exp%u"%(l,e)+".dat"), sep='\t')
    
    name = os.path.split(col.sim.base_name)[1]
    with open(os.path.join(output,"index_Cairo_1mT-1200s.dat"),'a',newline='') as file:
        writer = csv.writer(file,delimiter='\t')
        writer.writerow([name, l, e])

# %%
e =  np.arange(0,10)
l =  [10]
L, E = np.meshgrid(l,e)
experiments = pd.DataFrame({"e":E.flatten(),"l":L.flatten()})
experiments
# Out:
#    e   l
# 0  0  10
# 1  1  10
# 2  2  10
# 3  3  10
# 4  4  10
# 5  5  10
# 6  6  10
# 7  7  10
# 8  8  10
# 9  9  10

# %%
# %%time
if __name__ ==  '__main__': 
    num_processors = 10
    p=Pool(processes = num_processors)
    
    ## Create index text file
    if not os.path.exists(output):
        os.makedirs(output)
    with open(os.path.join(output,"index_Cairo_1mT-1200s.dat"),'w',newline='') as file:
        writer = csv.writer(file,delimiter='\t')
        writer.writerow(["filename", "l", "exp"])
        
    list(tqdm.tqdm(p.imap(do_everything, experiments.iterrows()), total=len(experiments)))
# Out:
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:62: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new[:,0] = centers_toAddX
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:62: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new[:,0] = centers_toAddX
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:63: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new[:,1] = centers_toAddY
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:63: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new[:,1] = centers_toAddY
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:62: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new[:,0] = centers_toAddX
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:63: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new[:,1] = centers_toAddY
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:62: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new[:,0] = centers_toAddX
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:170: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new_centers[:,1] = centersY
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:170: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new_centers[:,1] = centersY
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:63: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new[:,1] = centers_toAddY
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:62: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new[:,0] = centers_toAddX
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:170: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new_centers[:,1] = centersY
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:62: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new[:,0] = centers_toAddX
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:62: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new[:,0] = centers_toAddX
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:63: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new[:,1] = centers_toAddY
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:63: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new[:,1] = centers_toAddY
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:170: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new_centers[:,1] = centersY
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:63: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new[:,1] = centers_toAddY
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:62: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new[:,0] = centers_toAddX
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:63: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new[:,1] = centers_toAddY
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:170: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new_centers[:,1] = centersY
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:62: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new[:,0] = centers_toAddX
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:62: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new[:,0] = centers_toAddX
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:170: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new_centers[:,1] = centersY
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:170: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new_centers[:,1] = centersY
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:63: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new[:,1] = centers_toAddY
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:63: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new[:,1] = centers_toAddY
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:170: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new_centers[:,1] = centersY
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:170: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new_centers[:,1] = centersY
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:170: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new_centers[:,1] = centersY
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=197532557.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=197560973.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=197524000.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=197447340.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=197638044.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=197523970.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=197534256.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=197612535.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=197578113.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=197546606.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=197250055.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=197359128.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=197244413.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=197165339.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1201.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=197244350.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1201.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1201.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=197278491.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1201.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=197266174.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=197333103.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=197299413.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1201.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1201.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1201.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1201.0), HTML(value='')))
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=197254964.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1201.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1201.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# ...
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1208.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2000.0), HTML(value='')))
