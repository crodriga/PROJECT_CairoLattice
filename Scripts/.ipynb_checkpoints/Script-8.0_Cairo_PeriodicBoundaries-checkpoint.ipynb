# %% [markdown]
# # Cairo Periodic Boundaries
#
#     In this script, I will compute a Cairo lattice simulation but with periodic boundaries in order to observe if the evolution of charges is preserved with those.

# %%
import os
import sys
import numpy as np
from importlib import reload  
import support as sup
reload(sup)
sys.path.insert(0, '../icenumerics')

import icenumerics as ice

from icenumerics.geometry import ordering 
import magcolloids as mgc

import matplotlib.pyplot as plt
ureg = ice.ureg
from string import Template

# %load_ext autoreload
# %autoreload 2

# %%
output = "/home/carolina/CairoLattice_ACI_PROJECT/Scripts/Output_Script-8.0"

# %% [markdown]
#     To set correctly periodic boundaries I need to build a Cairo lattice but with a square structure. This way there will be a match of the vertices by only translating the lattice a certain quantity. To do that I need to re-draw the lattice. Let's start!

# %%
np.random.seed()

l = 6
a = 19.5458*ureg.um
sp = sup.spins()
ureg = ice.ureg
sp.create_lattice(geometry = "cairo",size =[l,l],lattice_constant=19.5458*ureg.um, border="periodic")
sp.order_spins(ordering.random_ordering)
# Out:
# /home/carolina/CairoLattice_ACI_PROJECT/Scripts/support.py:282: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   new_centers[:,1] = centersY

# %%
particle = ice.particle(radius = 5*ureg.um,
             susceptibility = 0.005,
             diffusion = 0.125*ureg.um**2/ureg.s,
             temperature = 300*ureg.K,
             density = 1000*ureg.kg/ureg.m**3)

trap_long = ice.trap(trap_sep = 10*ureg.um,
               height = 30*ureg.pN*ureg.nm,
               stiffness = 0.1*ureg.fN/ureg.nm)

trap_short = ice.trap(trap_sep = 4.5258*ureg.um,
               height = 30*ureg.pN*ureg.nm,
               stiffness = 0.1*ureg.fN/ureg.nm)

traps = []

# %%
for s in sp:
    
    if ( s.direction[0].magnitude == a.magnitude or s.direction[0].magnitude == -a.magnitude or 
        s.direction[1].magnitude == a.magnitude or s.direction[1].magnitude == -a.magnitude ):
        
        traps.append(trap_short)
        
    else:
        
        traps.append(trap_long)

# %%
col = ice.colloidal_ice(sp, particle, traps, height_spread = 0, susceptibility_spread = 0.1)

col.pad_region(5*ureg.um)

# %%
f, (ax1) = plt.subplots(1,1,figsize = (15,15))
col.display(ax1)
#plt.xlim(0,200)
#plt.ylim(0,-100)

# %%
world = ice.world(
    field = 25*ureg.mT,
    temperature = 300*ureg.K,
    dipole_cutoff = 200*ureg.um,
   boundaries = ["p", "p", "p"])

# %%
total_time = 100*ureg.s
col.simulate(world,
             name = "ACI_CairoLattice_l%u_15mT-800s"%(l),
             include_timestamp = False,
             targetdir = output,
             framerate = 1*ureg.Hz,
             timestep = 10*ureg.ms,
             run_time = total_time,
             output = ["x","y","z","mux","muy","muz"])
# Out:
# ../icenumerics/icenumerics/magcolloids/magcolloids/geometry.py:13: RuntimeWarning: invalid value encountered in multiply
#   c = np.empty([len(a),4])*np.NaN
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=5919523.0), HTML(value='')))

# %%
col.sim.field.fieldz = "v_Bmag"
col.run_simulation()

# %%
col.load_simulation(slice(0,None,1))
# Out:
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=5920005.0), HTML(value='')))

# %%
f, (ax1) = plt.subplots(1,1,figsize = (15,15))
col.display(ax1)

# %%
f, (ax1) = plt.subplots(1,1,figsize = (15,15))
v = ice.vertices()
col.set_state_from_frame(-1)
v = v.colloids_to_vertices(col)

col.display(ax1)
v.display(ax1)
v.vertices.groupby('charge').count()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=574.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=720.0), HTML(value='')))
# [19, 22, 83]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-c0ed710c6bf3> in <module>
#       2 v = ice.vertices()
#       3 col.set_state_from_frame(-1)
# ----> 4 v = v.colloids_to_vertices(col)
#       5
#       6 col.display(ax1)
#
# ~/CairoLattice_ACI_PROJECT/icenumerics/icenumerics/vertices.py in colloids_to_vertices(self, col)
#     307
#     308         spins = ice_to_spins(col)
# --> 309         self.infer_topology(spins)
#     310         self.classify_vertices(spins)
#     311
#
# ~/CairoLattice_ACI_PROJECT/icenumerics/icenumerics/vertices.py in infer_topology(self, ice, positions, method, tolerance)
#     260                                 for i,c in enumerate(copies)}
#     261
# --> 262         self.edges = create_edge_array(self.edge_directory, spins, positions)
#     263
#     264     def update_directions(self, ice):
#
# ~/CairoLattice_ACI_PROJECT/icenumerics/icenumerics/vertices.py in create_edge_array(edge_directory, spins, positions)
#     189
#     190     edges = np.array([[e,*where_is_edge(e, edge_directory)]
# --> 191                       for e in tqdm.tqdm(edge_ids)])
#     192
#     193     edges = pd.DataFrame(data = edges[:,1:],
#
# ~/CairoLattice_ACI_PROJECT/icenumerics/icenumerics/vertices.py in <listcomp>(.0)
#     189
#     190     edges = np.array([[e,*where_is_edge(e, edge_directory)]
# --> 191                       for e in tqdm.tqdm(edge_ids)])
#     192
#     193     edges = pd.DataFrame(data = edges[:,1:],
#
# ~/CairoLattice_ACI_PROJECT/icenumerics/icenumerics/vertices.py in where_is_edge(e, edge_directory)
#     149     if len(vertices)!=2:
#     150         print(vertices)
# --> 151         raise ValueError("edges can only join two vertices")
#     152
#     153     return vertices
#
# ValueError: edges can only join two vertices

# %%
np.cos(60*np.pi/180), np.sin(30*np.pi/180)
# Out:
# (0.5000000000000001, 0.49999999999999994)

# %% [markdown]
# # Old stuff

# %%
particle = ice.particle(radius = 5*ureg.um,
             susceptibility = 0.005,
             diffusion = 0.125*ureg.um**2/ureg.s,
             temperature = 300*ureg.K,
             density = 1000*ureg.kg/ureg.m**3)

trap_long = ice.trap(trap_sep = 10*ureg.um,
               height = 30*ureg.pN*ureg.nm,
               stiffness = 0.1*ureg.fN/ureg.nm)

trap_short = ice.trap(trap_sep = 4.5258*ureg.um,
               height = 30*ureg.pN*ureg.nm,
               stiffness = 0.1*ureg.fN/ureg.nm)

traps = []

# %%
for s in sp:
    
    if ( s.direction[0].magnitude == 1.0 or s.direction[0].magnitude == -1.0 or 
        s.direction[1].magnitude == 1.0 or s.direction[1].magnitude == -1.0 ):
        
        traps.append(trap_short)
        
    else:
        
        traps.append(trap_long)

# %%
col = ice.colloidal_ice(sp, particle, traps, height_spread = 0, susceptibility_spread = 0.1)

col.pad_region(5*ureg.um)

# %%
f, (ax1) = plt.subplots(1,1,figsize = (15,15))
col.display(ax1)

# %%
world = ice.world(
    field = 25*ureg.mT,
    temperature = 300*ureg.K,
    dipole_cutoff = 200*ureg.um,
   boundaries = ["p", "p", "p"])

# %%
total_time = 100*ureg.s
col.simulate(world,
             name = "ACI_CairoLattice_l%u_15mT-800s"%(l),
             include_timestamp = False,
             targetdir = output,
             framerate = 1*ureg.Hz,
             timestep = 10*ureg.ms,
             run_time = total_time,
             output = ["x","y","z","mux","muy","muz"])
# Out:
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=662386.0), HTML(value='')))

# %%
col.sim.field.fieldz = "v_Bmag"
col.run_simulation()

# %%
col.load_simulation(slice(0,None,1))
# Out:
# scanning file
# HBox(children=(FloatProgress(value=0.0, max=662466.0), HTML(value='')))

# %%
f, (ax1) = plt.subplots(1,1,figsize = (15,15))
v = ice.vertices()
col.set_state_from_frame(-1)
v = v.colloids_to_vertices(col)

col.display(ax1)
v.display(ax1)
v.vertices.groupby('charge').count()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=48.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=80.0), HTML(value='')))
#          x   y  coordination  dx  dy
# charge
# -2       5   5             5   5   5
# -1      16  16            16  16  16
#  0      13  13            13  13  13
#  1      12  12            12  12  12
#  2       2   2             2   2   2

# %% [markdown]
#     - Tiene que ser cuadrada la lattice?
#     - El border tiene que indicar periodic?
